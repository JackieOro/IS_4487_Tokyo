# %% [markdown]
# <a href="https://colab.research.google.com/github/JackieOro/IS_4487_Tokyo/blob/main/Day6_lab_megatelco_tree_model(I)__Jackie_Orozco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 6 Lab, IS 4487
#
# The purpose of this lab is to prepare you to complete today's project quiz. Here are the questions you need to be able to answer.
#
# - Understand model accuracy.  And:  Why is it a performance metric for classification and not regression?
# - Calculate accuracy for a simple majority class model (this is the same as calculating the proportion of the majority class in a binary variable).
# - Fit a tree model of the target with just one predictor variable and calculate the accuracy of this model.
# - Calculate accuracy for the tree model.
# - Explain how the classification tree algorithm chooses which variable to split on and where to split.
#
# Additionally will talk about cross validation and overfitting.

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd

# Import packages needed for the classification tree
from sklearn.tree import plot_tree
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, export_graphviz # Import Decision Tree Classifier

# %% [markdown]
# ## Get Data

# %%
mtc = pd.read_csv("https://raw.githubusercontent.com/jefftwebb/is_4487_base/dd870389117d5b24eee7417d5378d80496555130/Labs/DataSets/megatelco_leave_survey.csv")

# %% [markdown]
# ## Clean the data
#
# Perform the cleaning from the previous labs:
# - Remove negative values of income and house
# - Remove absurdly large value of handset_price
# - Remove NAs
# - Change `college` to `yes` and `no`
# - Make string variables into categorical variables. We've been using `astype("categorical")` to do that, but there is a better way when we also need to define an order among multiple levels.  This is important for plotting and for accurate modelling.
#
# Start by making `mtc_clean` an explicit copy.  This will avoid the warning you've been getting: "A value is trying to be set on a copy of a slice from a DataFrame."

# %%
# Make copy
mtc_clean = mtc.copy()

# %%
# filter rows
mtc_clean = mtc[(mtc['house'] > 0) & (mtc['income'] > 0) & (mtc['handset_price'] < 1000)]

# %%
# remove NAs
mtc_clean = mtc_clean.dropna()

# %%
# Recode college
mtc_clean['college'] = mtc_clean['college'].replace({'one': 'yes', 'zero': 'no'})

# %% [markdown]
# We'll use the `pd.Categorical()` function to simultaneously make the string variables categorical and set the levels.  The syntax is:
#
# `data['column'] = pd.Categorical(data['column'],
#   categories = list,
#   ordered = True)`
#
#   where "list" is the list of levels in order, such as:  `['small', 'medium', 'large']`. Without explicitly setting this order the default would be alphabetic:  large, medium, small.
#
#   Here's an example:

# %%
# Convert string to categorical variable
mtc_clean['leave'] = pd.Categorical(mtc_clean['leave'],
                                    categories = ['LEAVE', 'STAY'],
                                    ordered = True)

# %%
mtc_clean['leave'].dtype
# Out:
# CategoricalDtype(categories=['LEAVE', 'STAY'], ordered=True)

# %% [markdown]
# Looks good.
#
# Go ahead and do a similar transformation on the remainder of categorical variables:
#
# - `reported_satisfaction`
# - `reported_usage_level`
# - `considering_change_of_plan`
# - `college`

# %%
# Your code goes here
mtc_clean['reported_satisfaction'].unique()
# Out:
# array(['low', 'high', 'avg'], dtype=object)

# %%
mtc_clean['reported_satisfaction'].unique()
# Out:
# array(['low', 'high', 'avg'], dtype=object)

# %%
mtc_clean['considering_change_of_plan'].unique()
# Out:
# array(['yes', 'no', 'maybe'], dtype=object)

# %%
mtc_clean['college'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
# change college and considering change of plan
mtc_clean['college'] = mtc_clean['college'].astype('category')
mtc_clean['considering_change_of_plan'] = mtc_clean['considering_change_of_plan'].astype('category')

# %%
# change reported usage and reported satisfaction
mtc_clean['reported _usage_level']= pd.Categorical(mtc_clean['reported_usage_level'],
                                    categories = ['low', 'high', 'ave'],
                                    ordered = True)
mtc_clean['reported_satisfaction']= pd.Categorical(mtc_clean['reported_satisfaction'],
                                    categories = ['low', 'high', 'ave'],
                                    ordered = True)

# %% [markdown]
# ## Calculate the proportion of the majority class
# What is the proportion of customers who churned? Note that `len(data)` (where "data" is your data frame) returns a count of the number of observations.

# %%
# Your code goes here
mtc_clean['leave'].value_counts(normalize = True)
# Out:
# leave
# STAY     0.505807
# LEAVE    0.494193
# Name: proportion, dtype: float64

# %% [markdown]
# Why should we care?
#
# The majority class in the target variable will serve as an important benchmark for model performance. Predicting the majority class is the simplest possible classifier. We'll call it the "majority class classifier." It represents the best predictive guess you can make, in the absence of other information.  The accuracy of the majority class classifier is simply the proportion of the majority class in the data.
#
# Why is this?
#
# *Accuracy is defined as the proportion of correctly predicted labels. It is a commonly used error metric for evaluating classifier performance.*
#
# **Whatever later model we develop should have better accuracy than this performance benchmark.**

# %% [markdown]
# ## Fit a basic tree model
#
# Use just one variable, `income`. This is a very simple tree we'll call the "money tree."

# %%
# Step 1:  Initialize model, specifying
# 1. split criterion is entropy
# 2. max_depth = 2

money_tree = DecisionTreeClassifier(criterion = "entropy", max_depth = 2)

# %% [markdown]
# Explanation of code:
#
# - `DecisionTreeClassifier()`: Creates an instance of the decision tree classifier from scikit-learn
# - `criterion="entropy"`: Specifies the function to measure the quality of a split (entropy measures the impurity of the split)
# - `max_depth=2`: Limits the tree to a maximum depth of 2 levels, controlling complexity and preventing overfitting
# - Output: Returns a configured decision tree classifier object, ready to be fitted with data

# %%
# Step 2: Create Decision Tree Classifer, specifying
# 1. X (the predictor set) as income
# 2. y (the target) as leave

money_tree = money_tree.fit(X = mtc_clean[['income']],
                            y = mtc_clean['leave'])

# %% [markdown]
# Explanation of code:
#
# - `money_tree.fit()`: Trains the decision tree classifier on the provided data
# - `X = mtc_clean[['income']]`: Input feature (predictor), selecting only the `income` column *as a DataFrame* (note the double square brackets)
# - `y = mtc_clean['leave']`: Target variable, the `leave` column containing the class labels
# - Output: Returns the fitted decision tree model, now trained on the income data to predict customer churn
#
# Gemini prompt:  "what is the difference between double and single square brackets in Pandas for slicing?"

# %%
from sklearn.tree import export_text

print(export_text(money_tree, feature_names = ['income']))
# Out:
# |--- income <= 99993.00
# |   |--- income <= 20137.50
# |   |   |--- class: STAY
# |   |--- income >  20137.50
# |   |   |--- income <= 20247.50
# |   |   |   |--- class: LEAVE
# |   |   |--- income >  20247.50
# |   |   |   |--- income <= 25346.00
# |   |   |   |   |--- income <= 23245.00
# |   |   |   |   |   |--- income <= 23190.00
# |   |   |   |   |   |   |--- income <= 23135.00
# |   |   |   |   |   |   |   |--- income <= 22596.50
# |   |   |   |   |   |   |   |   |--- income <= 22512.00
# |   |   |   |   |   |   |   |   |   |--- income <= 22435.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 22262.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 29
# |   |   |   |   |   |   |   |   |   |   |--- income >  22262.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- income >  22435.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- income >  22512.00
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- income >  22596.50
# |   |   |   |   |   |   |   |   |--- income <= 22773.50
# |   |   |   |   |   |   |   |   |   |--- income <= 22640.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 22634.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- income >  22634.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- income >  22640.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- income >  22773.50
# |   |   |   |   |   |   |   |   |   |--- income <= 22963.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 22855.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- income >  22855.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- income >  22963.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 23086.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- income >  23086.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- income >  23135.00
# |   |   |   |   |   |   |   |--- income <= 23161.00
# |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- income >  23161.00
# |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |--- income >  23190.00
# |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |--- income >  23245.00
# |   |   |   |   |   |--- income <= 23481.50
# |   |   |   |   |   |   |--- income <= 23350.00
# |   |   |   |   |   |   |   |--- income <= 23302.50
# |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- income >  23302.50
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |--- income >  23350.00
# |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |--- income >  23481.50
# |   |   |   |   |   |   |--- income <= 25324.50
# |   |   |   |   |   |   |   |--- income <= 23487.00
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- income >  23487.00
# |   |   |   |   |   |   |   |   |--- income <= 23496.50
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- income >  23496.50
# |   |   |   |   |   |   |   |   |   |--- income <= 23534.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  23534.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 23730.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- income >  23730.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |--- income >  25324.50
# |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |--- income >  25346.00
# |   |   |   |   |--- income <= 27265.00
# |   |   |   |   |   |--- income <= 27048.00
# |   |   |   |   |   |   |--- income <= 25556.00
# |   |   |   |   |   |   |   |--- income <= 25473.50
# |   |   |   |   |   |   |   |   |--- income <= 25429.50
# |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- income >  25429.50
# |   |   |   |   |   |   |   |   |   |--- income <= 25440.50
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- income >  25440.50
# |   |   |   |   |   |   |   |   |   |   |--- income <= 25456.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- income >  25456.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- income >  25473.50
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |--- income >  25556.00
# |   |   |   |   |   |   |   |--- income <= 25630.50
# |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- income >  25630.50
# |   |   |   |   |   |   |   |   |--- income <= 26999.00
# |   |   |   |   |   |   |   |   |   |--- income <= 26887.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 26877.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |   |--- income >  26877.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- income >  26887.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- income >  26999.00
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |--- income >  27048.00
# |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |--- income >  27265.00
# |   |   |   |   |   |--- income <= 27358.00
# |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |--- income >  27358.00
# |   |   |   |   |   |   |--- income <= 27898.00
# |   |   |   |   |   |   |   |--- income <= 27585.50
# |   |   |   |   |   |   |   |   |--- income <= 27482.50
# |   |   |   |   |   |   |   |   |   |--- income <= 27407.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 27391.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- income >  27391.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  27407.00
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- income >  27482.50
# |   |   |   |   |   |   |   |   |   |--- income <= 27553.50
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  27553.50
# |   |   |   |   |   |   |   |   |   |   |--- income <= 27577.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- income >  27577.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- income >  27585.50
# |   |   |   |   |   |   |   |   |--- income <= 27715.50
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- income >  27715.50
# |   |   |   |   |   |   |   |   |   |--- income <= 27741.50
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  27741.50
# |   |   |   |   |   |   |   |   |   |   |--- income <= 27754.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- income >  27754.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- income >  27898.00
# |   |   |   |   |   |   |   |--- income <= 29616.00
# |   |   |   |   |   |   |   |   |--- income <= 29110.00
# |   |   |   |   |   |   |   |   |   |--- income <= 27917.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  27917.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 28920.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- income >  28920.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- income >  29110.00
# |   |   |   |   |   |   |   |   |   |--- income <= 29406.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  29406.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 29509.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- income >  29509.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- income >  29616.00
# |   |   |   |   |   |   |   |   |--- income <= 31012.50
# |   |   |   |   |   |   |   |   |   |--- income <= 29860.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 29626.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- income >  29626.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- income >  29860.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 29993.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- income >  29993.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |--- income >  31012.50
# |   |   |   |   |   |   |   |   |   |--- income <= 33653.50
# |   |   |   |   |   |   |   |   |   |   |--- income <= 33312.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 22
# |   |   |   |   |   |   |   |   |   |   |--- income >  33312.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  33653.50
# |   |   |   |   |   |   |   |   |   |   |--- income <= 33738.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- income >  33738.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 90
# |--- income >  99993.00
# |   |--- income <= 159576.00
# |   |   |--- income <= 105440.00
# |   |   |   |--- income <= 104820.00
# |   |   |   |   |--- income <= 101080.00
# |   |   |   |   |   |--- income <= 100973.50
# |   |   |   |   |   |   |--- income <= 100935.00
# |   |   |   |   |   |   |   |--- income <= 100822.50
# |   |   |   |   |   |   |   |   |--- income <= 100809.00
# |   |   |   |   |   |   |   |   |   |--- income <= 100592.50
# |   |   |   |   |   |   |   |   |   |   |--- income <= 100032.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- income >  100032.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- income >  100592.50
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- income >  100809.00
# |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- income >  100822.50
# |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |--- income >  100935.00
# |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |--- income >  100973.50
# |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |--- income >  101080.00
# |   |   |   |   |   |--- income <= 101850.50
# |   |   |   |   |   |   |--- income <= 101507.00
# |   |   |   |   |   |   |   |--- income <= 101450.00
# |   |   |   |   |   |   |   |   |--- income <= 101345.00
# |   |   |   |   |   |   |   |   |   |--- income <= 101118.50
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  101118.50
# |   |   |   |   |   |   |   |   |   |   |--- income <= 101140.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- income >  101140.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- income >  101345.00
# |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- income >  101450.00
# |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |--- income >  101507.00
# |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |--- income >  101850.50
# |   |   |   |   |   |   |--- income <= 102185.00
# |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |--- income >  102185.00
# |   |   |   |   |   |   |   |--- income <= 102249.50
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- income >  102249.50
# |   |   |   |   |   |   |   |   |--- income <= 104785.50
# |   |   |   |   |   |   |   |   |   |--- income <= 104456.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 104396.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- income >  104396.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  104456.00
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- income >  104785.50
# |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |--- income >  104820.00
# |   |   |   |   |--- class: LEAVE
# |   |   |--- income >  105440.00
# |   |   |   |--- income <= 153493.00
# |   |   |   |   |--- income <= 147861.50
# |   |   |   |   |   |--- income <= 143958.00
# |   |   |   |   |   |   |--- income <= 143167.00
# |   |   |   |   |   |   |   |--- income <= 143071.00
# |   |   |   |   |   |   |   |   |--- income <= 105612.00
# |   |   |   |   |   |   |   |   |   |--- income <= 105472.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 105457.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- income >  105457.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- income >  105472.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- income >  105612.00
# |   |   |   |   |   |   |   |   |   |--- income <= 141487.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 141208.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 98
# |   |   |   |   |   |   |   |   |   |   |--- income >  141208.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  141487.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 142266.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- income >  142266.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |--- income >  143071.00
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |--- income >  143167.00
# |   |   |   |   |   |   |   |--- income <= 143477.00
# |   |   |   |   |   |   |   |   |--- income <= 143272.00
# |   |   |   |   |   |   |   |   |   |--- income <= 143251.50
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- income >  143251.50
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- income >  143272.00
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- income >  143477.00
# |   |   |   |   |   |   |   |   |--- income <= 143900.50
# |   |   |   |   |   |   |   |   |   |--- income <= 143513.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  143513.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 143606.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- income >  143606.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- income >  143900.50
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |--- income >  143958.00
# |   |   |   |   |   |   |--- income <= 145053.50
# |   |   |   |   |   |   |   |--- income <= 144426.00
# |   |   |   |   |   |   |   |   |--- income <= 144370.50
# |   |   |   |   |   |   |   |   |   |--- income <= 144055.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 144028.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- income >  144028.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- income >  144055.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- income >  144370.50
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- income >  144426.00
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |--- income >  145053.50
# |   |   |   |   |   |   |   |--- income <= 147730.50
# |   |   |   |   |   |   |   |   |--- income <= 145938.00
# |   |   |   |   |   |   |   |   |   |--- income <= 145772.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 145687.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- income >  145687.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  145772.00
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- income >  145938.00
# |   |   |   |   |   |   |   |   |   |--- income <= 145966.50
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  145966.50
# |   |   |   |   |   |   |   |   |   |   |--- income <= 146076.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- income >  146076.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |--- income >  147730.50
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |--- income >  147861.50
# |   |   |   |   |   |--- income <= 148332.00
# |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |--- income >  148332.00
# |   |   |   |   |   |   |--- income <= 148417.50
# |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |--- income >  148417.50
# |   |   |   |   |   |   |   |--- income <= 149247.50
# |   |   |   |   |   |   |   |   |--- income <= 148607.00
# |   |   |   |   |   |   |   |   |   |--- income <= 148504.50
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- income >  148504.50
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- income >  148607.00
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- income >  149247.50
# |   |   |   |   |   |   |   |   |--- income <= 149404.50
# |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- income >  149404.50
# |   |   |   |   |   |   |   |   |   |--- income <= 153313.50
# |   |   |   |   |   |   |   |   |   |   |--- income <= 153177.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- income >  153177.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  153313.50
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |--- income >  153493.00
# |   |   |   |   |--- income <= 153705.50
# |   |   |   |   |   |--- class: STAY
# |   |   |   |   |--- income >  153705.50
# |   |   |   |   |   |--- income <= 156585.00
# |   |   |   |   |   |   |--- income <= 153747.50
# |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |--- income >  153747.50
# |   |   |   |   |   |   |   |--- income <= 156510.50
# |   |   |   |   |   |   |   |   |--- income <= 156436.50
# |   |   |   |   |   |   |   |   |   |--- income <= 156356.00
# |   |   |   |   |   |   |   |   |   |   |--- income <= 156195.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- income >  156195.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- income >  156356.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- income >  156436.50
# |   |   |   |   |   |   |   |   |   |--- income <= 156462.50
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- income >  156462.50
# |   |   |   |   |   |   |   |   |   |   |--- income <= 156482.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- income >  156482.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- income >  156510.50
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |--- income >  156585.00
# |   |   |   |   |   |   |--- income <= 156714.00
# |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |--- income >  156714.00
# |   |   |   |   |   |   |   |--- income <= 156766.00
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- income >  156766.00
# |   |   |   |   |   |   |   |   |--- income <= 157566.50
# |   |   |   |   |   |   |   |   |   |--- income <= 157455.50
# |   |   |   |   |   |   |   |   |   |   |--- income <= 157446.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- income >  157446.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  157455.50
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- income >  157566.50
# |   |   |   |   |   |   |   |   |   |--- income <= 158151.50
# |   |   |   |   |   |   |   |   |   |   |--- income <= 157958.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- income >  157958.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- income >  158151.50
# |   |   |   |   |   |   |   |   |   |   |--- income <= 158393.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- income >  158393.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |--- income >  159576.00
# |   |   |--- class: LEAVE

# %%
# Step 3: Visualize the money tree model
plot_tree(money_tree,
          feature_names=[['income']],
          class_names=['STAY', 'LEAVE'],
          filled=True)
# Out:
# [Text(0.4803931832201834, 0.9954128440366973, "['income'] <= 99993.0\nentropy = 1.0\nsamples = 3995\nvalue = [1984, 2011]\nclass = LEAVE"),
#  Text(0.0995652572536176, 0.9862385321100917, "['income'] <= 20137.5\nentropy = 0.991\nsamples = 2654\nvalue = [1180, 1474]\nclass = LEAVE"),
#  Text(0.0980799206014852, 0.9770642201834863, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.10105059390575002, 0.9770642201834863, "['income'] <= 20247.5\nentropy = 0.991\nsamples = 2651\nvalue = [1180, 1471]\nclass = LEAVE"),
#  Text(0.0995652572536176, 0.9678899082568807, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = STAY'),
#  Text(0.10253593055788243, 0.9678899082568807, "['income'] <= 25346.0\nentropy = 0.991\nsamples = 2647\nvalue = [1176, 1471]\nclass = LEAVE"),
#  Text(0.057139044336718854, 0.9587155963302753, "['income'] <= 23245.0\nentropy = 1.0\nsamples = 253\nvalue = [125, 128]\nclass = LEAVE"),
#  Text(0.04985161138719419, 0.9495412844036697, "['income'] <= 23190.0\nentropy = 0.988\nsamples = 142\nvalue = [62, 80]\nclass = LEAVE"),
#  Text(0.048366274735061776, 0.9403669724770642, "['income'] <= 23135.0\nentropy = 0.993\nsamples = 138\nvalue = [62, 76]\nclass = LEAVE"),
#  Text(0.0432604299933566, 0.9311926605504587, "['income'] <= 22596.5\nentropy = 0.988\nsamples = 133\nvalue = [58, 75]\nclass = LEAVE"),
#  Text(0.03750475046634349, 0.9220183486238532, "['income'] <= 22512.0\nentropy = 0.997\nsamples = 109\nvalue = [51, 58]\nclass = LEAVE"),
#  Text(0.036019413814211074, 0.9128440366972477, "['income'] <= 22435.0\nentropy = 0.994\nsamples = 106\nvalue = [48, 58]\nclass = LEAVE"),
#  Text(0.03453407716207866, 0.9036697247706422, "['income'] <= 22262.5\nentropy = 0.997\nsamples = 103\nvalue = [48, 55]\nclass = LEAVE"),
#  Text(0.029706733042648308, 0.8944954128440367, "['income'] <= 21969.0\nentropy = 0.988\nsamples = 94\nvalue = [41, 53]\nclass = LEAVE"),
#  Text(0.024508054760184854, 0.8853211009174312, "['income'] <= 21799.5\nentropy = 0.998\nsamples = 80\nvalue = [38, 42]\nclass = LEAVE"),
#  Text(0.021537381455920025, 0.8761467889908257, "['income'] <= 21664.5\nentropy = 0.988\nsamples = 69\nvalue = [30, 39]\nclass = LEAVE"),
#  Text(0.020052044803787607, 0.8669724770642202, "['income'] <= 21617.5\nentropy = 0.998\nsamples = 63\nvalue = [30, 33]\nclass = LEAVE"),
#  Text(0.018566708151655193, 0.8577981651376146, "['income'] <= 21427.5\nentropy = 0.995\nsamples = 61\nvalue = [28, 33]\nclass = LEAVE"),
#  Text(0.014853366521324154, 0.8486238532110092, "['income'] <= 21272.5\nentropy = 1.0\nsamples = 55\nvalue = [27, 28]\nclass = LEAVE"),
#  Text(0.01336802986919174, 0.8394495412844036, "['income'] <= 20463.0\nentropy = 0.996\nsamples = 52\nvalue = [24, 28]\nclass = LEAVE"),
#  Text(0.007426683260662077, 0.8302752293577982, "['income'] <= 20387.0\nentropy = 0.89\nsamples = 13\nvalue = [4, 9]\nclass = LEAVE"),
#  Text(0.005941346608529662, 0.8211009174311926, "['income'] <= 20284.0\nentropy = 0.991\nsamples = 9\nvalue = [4, 5]\nclass = LEAVE"),
#  Text(0.0044560099563972465, 0.8119266055045872, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.007426683260662077, 0.8119266055045872, "['income'] <= 20351.0\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]\nclass = STAY"),
#  Text(0.0044560099563972465, 0.8027522935779816, "['income'] <= 20318.0\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = STAY"),
#  Text(0.002970673304264831, 0.7935779816513762, "['income'] <= 20300.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.0014853366521324154, 0.7844036697247706, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.0044560099563972465, 0.7844036697247706, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.005941346608529662, 0.7935779816513762, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.010397356564926907, 0.8027522935779816, "['income'] <= 20379.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = LEAVE"),
#  Text(0.008912019912794493, 0.7935779816513762, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.011882693217059323, 0.7935779816513762, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY'),
#  Text(0.008912019912794493, 0.8211009174311926, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = LEAVE'),
#  Text(0.0193093764777214, 0.8302752293577982, "['income'] <= 20507.5\nentropy = 1.0\nsamples = 39\nvalue = [20, 19]\nclass = STAY"),
#  Text(0.017824039825588986, 0.8211009174311926, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.020794713129853815, 0.8211009174311926, "['income'] <= 20606.5\nentropy = 0.999\nsamples = 37\nvalue = [18, 19]\nclass = LEAVE"),
#  Text(0.017824039825588986, 0.8119266055045872, "['income'] <= 20553.0\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = LEAVE"),
#  Text(0.01633870317345657, 0.8027522935779816, "['income'] <= 20534.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.014853366521324154, 0.7935779816513762, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.017824039825588986, 0.7935779816513762, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.0193093764777214, 0.8027522935779816, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.023765386434118647, 0.8119266055045872, "['income'] <= 21230.0\nentropy = 0.997\nsamples = 32\nvalue = [17, 15]\nclass = STAY"),
#  Text(0.022280049781986232, 0.8027522935779816, "['income'] <= 20627.0\nentropy = 0.993\nsamples = 31\nvalue = [17, 14]\nclass = STAY"),
#  Text(0.020794713129853815, 0.7935779816513762, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.023765386434118647, 0.7935779816513762, "['income'] <= 20677.0\nentropy = 0.997\nsamples = 30\nvalue = [16, 14]\nclass = STAY"),
#  Text(0.022280049781986232, 0.7844036697247706, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.02525072308625106, 0.7844036697247706, "['income'] <= 20732.0\nentropy = 0.992\nsamples = 29\nvalue = [16, 13]\nclass = STAY"),
#  Text(0.023765386434118647, 0.7752293577981652, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.02673605973838348, 0.7752293577981652, "['income'] <= 20746.5\nentropy = 0.999\nsamples = 27\nvalue = [14, 13]\nclass = STAY"),
#  Text(0.02525072308625106, 0.7660550458715596, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.028221396390515893, 0.7660550458715596, "['income'] <= 20777.5\nentropy = 0.99\nsamples = 25\nvalue = [14, 11]\nclass = STAY"),
#  Text(0.02673605973838348, 0.7568807339449541, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.029706733042648308, 0.7568807339449541, "['income'] <= 20878.5\nentropy = 1.0\nsamples = 22\nvalue = [11, 11]\nclass = STAY"),
#  Text(0.028221396390515893, 0.7477064220183486, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.031192069694780725, 0.7477064220183486, "['income'] <= 20982.0\nentropy = 0.982\nsamples = 19\nvalue = [11, 8]\nclass = STAY"),
#  Text(0.029706733042648308, 0.7385321100917431, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.03267740634691314, 0.7385321100917431, "['income'] <= 21036.5\nentropy = 1.0\nsamples = 16\nvalue = [8, 8]\nclass = STAY"),
#  Text(0.031192069694780725, 0.7293577981651376, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.03416274299904556, 0.7293577981651376, "['income'] <= 21068.5\nentropy = 0.985\nsamples = 14\nvalue = [8, 6]\nclass = STAY"),
#  Text(0.03267740634691314, 0.7201834862385321, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.03564807965117797, 0.7201834862385321, "['income'] <= 21098.0\nentropy = 1.0\nsamples = 12\nvalue = [6, 6]\nclass = STAY"),
#  Text(0.03416274299904556, 0.7110091743119266, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.037133416303310386, 0.7110091743119266, "['income'] <= 21109.5\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]\nclass = STAY"),
#  Text(0.03564807965117797, 0.7018348623853211, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.0386187529554428, 0.7018348623853211, "['income'] <= 21114.0\nentropy = 0.991\nsamples = 9\nvalue = [5, 4]\nclass = STAY"),
#  Text(0.037133416303310386, 0.6926605504587156, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.040104089607575215, 0.6926605504587156, "['income'] <= 21125.5\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]\nclass = STAY"),
#  Text(0.0386187529554428, 0.6834862385321101, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.04158942625970763, 0.6834862385321101, "['income'] <= 21157.0\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = STAY"),
#  Text(0.040104089607575215, 0.6743119266055045, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.04307476291184005, 0.6743119266055045, "['income'] <= 21183.0\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]\nclass = STAY"),
#  Text(0.04158942625970763, 0.6651376146788991, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.044560099563972465, 0.6651376146788991, "['income'] <= 21190.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = STAY"),
#  Text(0.04307476291184005, 0.6559633027522935, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.04604543621610488, 0.6559633027522935, "['income'] <= 21213.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = STAY"),
#  Text(0.044560099563972465, 0.6467889908256881, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.047530772868237293, 0.6467889908256881, "['income'] <= 21221.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.04604543621610488, 0.6376146788990825, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.04901610952036971, 0.6376146788990825, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.02525072308625106, 0.8027522935779816, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.01633870317345657, 0.8394495412844036, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.022280049781986232, 0.8486238532110092, "['income'] <= 21485.0\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = LEAVE"),
#  Text(0.020794713129853815, 0.8394495412844036, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.023765386434118647, 0.8394495412844036, "['income'] <= 21501.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = LEAVE"),
#  Text(0.022280049781986232, 0.8302752293577982, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.02525072308625106, 0.8302752293577982, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.021537381455920025, 0.8577981651376146, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.02302271810805244, 0.8669724770642202, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = LEAVE'),
#  Text(0.027478728064449686, 0.8761467889908257, "['income'] <= 21856.0\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]\nclass = STAY"),
#  Text(0.02599339141231727, 0.8669724770642202, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.0289640647165821, 0.8669724770642202, "['income'] <= 21872.0\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]\nclass = STAY"),
#  Text(0.027478728064449686, 0.8577981651376146, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.030449401368714518, 0.8577981651376146, "['income'] <= 21898.0\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = STAY"),
#  Text(0.0289640647165821, 0.8486238532110092, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.03193473802084693, 0.8486238532110092, "['income'] <= 21907.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = STAY"),
#  Text(0.030449401368714518, 0.8394495412844036, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.03342007467297935, 0.8394495412844036, "['income'] <= 21932.0\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = STAY"),
#  Text(0.03193473802084693, 0.8302752293577982, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.03490541132511176, 0.8302752293577982, "['income'] <= 21942.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.03342007467297935, 0.8211009174311926, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.036390747977244176, 0.8211009174311926, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.03490541132511176, 0.8853211009174312, "['income'] <= 22078.0\nentropy = 0.75\nsamples = 14\nvalue = [3, 11]\nclass = LEAVE"),
#  Text(0.03342007467297935, 0.8761467889908257, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.036390747977244176, 0.8761467889908257, "['income'] <= 22098.5\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]\nclass = LEAVE"),
#  Text(0.03490541132511176, 0.8669724770642202, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.0378760846293766, 0.8669724770642202, "['income'] <= 22194.0\nentropy = 0.722\nsamples = 10\nvalue = [2, 8]\nclass = LEAVE"),
#  Text(0.036390747977244176, 0.8577981651376146, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = LEAVE'),
#  Text(0.03936142128150901, 0.8577981651376146, "['income'] <= 22241.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = LEAVE"),
#  Text(0.0378760846293766, 0.8486238532110092, "['income'] <= 22212.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = STAY"),
#  Text(0.036390747977244176, 0.8394495412844036, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.03936142128150901, 0.8394495412844036, "['income'] <= 22227.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.0378760846293766, 0.8302752293577982, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.040846757933641425, 0.8302752293577982, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.040846757933641425, 0.8486238532110092, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.03936142128150901, 0.8944954128440367, "['income'] <= 22313.5\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]\nclass = STAY"),
#  Text(0.0378760846293766, 0.8853211009174312, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.040846757933641425, 0.8853211009174312, "['income'] <= 22349.5\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = STAY"),
#  Text(0.03936142128150901, 0.8761467889908257, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.04233209458577384, 0.8761467889908257, "['income'] <= 22399.0\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]\nclass = STAY"),
#  Text(0.040846757933641425, 0.8669724770642202, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.043817431237906254, 0.8669724770642202, "['income'] <= 22415.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = STAY"),
#  Text(0.04233209458577384, 0.8577981651376146, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.04530276789003867, 0.8577981651376146, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.03750475046634349, 0.9036697247706422, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.0389900871184759, 0.9128440366972477, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.04901610952036971, 0.9220183486238532, "['income'] <= 22773.5\nentropy = 0.871\nsamples = 24\nvalue = [7, 17]\nclass = LEAVE"),
#  Text(0.04530276789003867, 0.9128440366972477, "['income'] <= 22640.0\nentropy = 0.469\nsamples = 10\nvalue = [1, 9]\nclass = LEAVE"),
#  Text(0.043817431237906254, 0.9036697247706422, "['income'] <= 22634.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = LEAVE"),
#  Text(0.04233209458577384, 0.8944954128440367, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.04530276789003867, 0.8944954128440367, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.04678810454217109, 0.9036697247706422, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = LEAVE'),
#  Text(0.05272945115070075, 0.9128440366972477, "['income'] <= 22963.0\nentropy = 0.985\nsamples = 14\nvalue = [6, 8]\nclass = LEAVE"),
#  Text(0.04975877784643592, 0.9036697247706422, "['income'] <= 22855.0\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]\nclass = STAY"),
#  Text(0.048273441194303504, 0.8944954128440367, "['income'] <= 22785.0\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]\nclass = STAY"),
#  Text(0.04678810454217109, 0.8853211009174312, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.04975877784643592, 0.8853211009174312, "['income'] <= 22793.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = LEAVE"),
#  Text(0.048273441194303504, 0.8761467889908257, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.05124411449856833, 0.8761467889908257, "['income'] <= 22806.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = STAY"),
#  Text(0.04975877784643592, 0.8669724770642202, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.05272945115070075, 0.8669724770642202, "['income'] <= 22819.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = LEAVE"),
#  Text(0.05124411449856833, 0.8577981651376146, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.05421478780283316, 0.8577981651376146, "['income'] <= 22828.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.05272945115070075, 0.8486238532110092, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.055700124454965576, 0.8486238532110092, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.05124411449856833, 0.8944954128440367, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.055700124454965576, 0.9036697247706422, "['income'] <= 23086.5\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = LEAVE"),
#  Text(0.05421478780283316, 0.8944954128440367, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.057185461107098, 0.8944954128440367, "['income'] <= 23108.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = LEAVE"),
#  Text(0.055700124454965576, 0.8853211009174312, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.05867079775923041, 0.8853211009174312, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.05347211947676696, 0.9311926605504587, "['income'] <= 23161.0\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = STAY"),
#  Text(0.05198678282463454, 0.9220183486238532, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.05495745612889937, 0.9220183486238532, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY'),
#  Text(0.05133694803932661, 0.9403669724770642, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = LEAVE'),
#  Text(0.06442647728624352, 0.9495412844036697, "['income'] <= 23481.5\nentropy = 0.987\nsamples = 111\nvalue = [63, 48]\nclass = STAY"),
#  Text(0.06145580398197869, 0.9403669724770642, "['income'] <= 23350.0\nentropy = 0.469\nsamples = 10\nvalue = [9, 1]\nclass = STAY"),
#  Text(0.059970467329846275, 0.9311926605504587, "['income'] <= 23302.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = STAY"),
#  Text(0.05848513067771386, 0.9220183486238532, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.06145580398197869, 0.9220183486238532, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.0629411406341111, 0.9311926605504587, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = STAY'),
#  Text(0.06739715059050835, 0.9403669724770642, "['income'] <= 25324.5\nentropy = 0.997\nsamples = 101\nvalue = [54, 47]\nclass = STAY"),
#  Text(0.06591181393837593, 0.9311926605504587, "['income'] <= 23487.0\nentropy = 0.999\nsamples = 98\nvalue = [51, 47]\nclass = STAY"),
#  Text(0.06442647728624352, 0.9220183486238532, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.06739715059050835, 0.9220183486238532, "['income'] <= 23496.5\nentropy = 0.998\nsamples = 97\nvalue = [51, 46]\nclass = STAY"),
#  Text(0.06591181393837593, 0.9128440366972477, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.06888248724264076, 0.9128440366972477, "['income'] <= 23534.0\nentropy = 0.999\nsamples = 95\nvalue = [49, 46]\nclass = STAY"),
#  Text(0.06739715059050835, 0.9036697247706422, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.07036782389477318, 0.9036697247706422, "['income'] <= 23730.0\nentropy = 0.997\nsamples = 92\nvalue = [49, 43]\nclass = STAY"),
#  Text(0.06312680771562766, 0.8944954128440367, "['income'] <= 23622.0\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]\nclass = STAY"),
#  Text(0.06164147106349524, 0.8853211009174312, "['income'] <= 23580.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = STAY"),
#  Text(0.060156134411362826, 0.8761467889908257, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.06312680771562766, 0.8761467889908257, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.06461214436776007, 0.8853211009174312, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.0776088400739187, 0.8944954128440367, "['income'] <= 24014.5\nentropy = 1.0\nsamples = 86\nvalue = [44, 42]\nclass = STAY"),
#  Text(0.0675828176720249, 0.8853211009174312, "['income'] <= 23881.5\nentropy = 0.937\nsamples = 17\nvalue = [6, 11]\nclass = LEAVE"),
#  Text(0.06609748101989249, 0.8761467889908257, "['income'] <= 23857.0\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]\nclass = STAY"),
#  Text(0.06461214436776007, 0.8669724770642202, "['income'] <= 23736.0\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]\nclass = STAY"),
#  Text(0.06312680771562766, 0.8577981651376146, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.06609748101989249, 0.8577981651376146, "['income'] <= 23777.0\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = STAY"),
#  Text(0.06461214436776007, 0.8486238532110092, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.0675828176720249, 0.8486238532110092, "['income'] <= 23814.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = LEAVE"),
#  Text(0.06609748101989249, 0.8394495412844036, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.06906815432415732, 0.8394495412844036, "['income'] <= 23837.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = STAY"),
#  Text(0.0675828176720249, 0.8302752293577982, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.07055349097628974, 0.8302752293577982, "['income'] <= 23848.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = LEAVE"),
#  Text(0.06906815432415732, 0.8211009174311926, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.07203882762842215, 0.8211009174311926, "['income'] <= 23853.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.07055349097628974, 0.8119266055045872, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.07352416428055457, 0.8119266055045872, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.0675828176720249, 0.8669724770642202, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.06906815432415732, 0.8761467889908257, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = LEAVE'),
#  Text(0.08763486247581251, 0.8853211009174312, "['income'] <= 24322.0\nentropy = 0.993\nsamples = 69\nvalue = [38, 31]\nclass = STAY"),
#  Text(0.08392152084548148, 0.8761467889908257, "['income'] <= 24298.5\nentropy = 0.779\nsamples = 13\nvalue = [10, 3]\nclass = STAY"),
#  Text(0.08243618419334905, 0.8669724770642202, "['income'] <= 24281.5\nentropy = 0.881\nsamples = 10\nvalue = [7, 3]\nclass = STAY"),
#  Text(0.08095084754121665, 0.8577981651376146, "['income'] <= 24161.0\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]\nclass = STAY"),
#  Text(0.07946551088908423, 0.8486238532110092, "['income'] <= 24117.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = STAY"),
#  Text(0.0779801742369518, 0.8394495412844036, "['income'] <= 24054.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = STAY"),
#  Text(0.0764948375848194, 0.8302752293577982, "['income'] <= 24043.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.07500950093268698, 0.8211009174311926, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.0779801742369518, 0.8211009174311926, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.07946551088908423, 0.8302752293577982, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.08095084754121665, 0.8394495412844036, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.08243618419334905, 0.8486238532110092, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = STAY'),
#  Text(0.08392152084548148, 0.8577981651376146, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.08540685749761388, 0.8669724770642202, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.09134820410614355, 0.8761467889908257, "['income'] <= 24500.0\nentropy = 1.0\nsamples = 56\nvalue = [28, 28]\nclass = STAY"),
#  Text(0.08837753080187871, 0.8669724770642202, "['income'] <= 24428.5\nentropy = 0.684\nsamples = 11\nvalue = [2, 9]\nclass = LEAVE"),
#  Text(0.0868921941497463, 0.8577981651376146, "['income'] <= 24396.0\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]\nclass = LEAVE"),
#  Text(0.08540685749761388, 0.8486238532110092, "['income'] <= 24337.0\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = LEAVE"),
#  Text(0.08392152084548148, 0.8394495412844036, "['income'] <= 24325.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.08243618419334905, 0.8302752293577982, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.08540685749761388, 0.8302752293577982, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.0868921941497463, 0.8394495412844036, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = LEAVE'),
#  Text(0.08837753080187871, 0.8486238532110092, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.08986286745401113, 0.8577981651376146, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = LEAVE'),
#  Text(0.09431887741040838, 0.8669724770642202, "['income'] <= 24569.5\nentropy = 0.982\nsamples = 45\nvalue = [26, 19]\nclass = STAY"),
#  Text(0.09283354075827596, 0.8577981651376146, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = STAY'),
#  Text(0.09580421406254079, 0.8577981651376146, "['income'] <= 24580.5\nentropy = 1.0\nsamples = 39\nvalue = [20, 19]\nclass = STAY"),
#  Text(0.09431887741040838, 0.8486238532110092, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.09728955071467321, 0.8486238532110092, "['income'] <= 24623.0\nentropy = 0.998\nsamples = 38\nvalue = [20, 18]\nclass = STAY"),
#  Text(0.09580421406254079, 0.8394495412844036, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.09877488736680563, 0.8394495412844036, "['income'] <= 24646.0\nentropy = 1.0\nsamples = 36\nvalue = [18, 18]\nclass = STAY"),
#  Text(0.09728955071467321, 0.8302752293577982, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.10026022401893804, 0.8302752293577982, "['income'] <= 25304.5\nentropy = 0.998\nsamples = 34\nvalue = [18, 16]\nclass = STAY"),
#  Text(0.09877488736680563, 0.8211009174311926, "['income'] <= 25097.0\nentropy = 0.994\nsamples = 33\nvalue = [18, 15]\nclass = STAY"),
#  Text(0.09580421406254079, 0.8119266055045872, "['income'] <= 25072.5\nentropy = 0.999\nsamples = 25\nvalue = [12, 13]\nclass = LEAVE"),
#  Text(0.09431887741040838, 0.8027522935779816, "['income'] <= 25062.5\nentropy = 0.999\nsamples = 23\nvalue = [12, 11]\nclass = STAY"),
#  Text(0.09283354075827596, 0.7935779816513762, "['income'] <= 25005.5\nentropy = 1.0\nsamples = 22\nvalue = [11, 11]\nclass = STAY"),
#  Text(0.09134820410614355, 0.7844036697247706, "['income'] <= 24980.0\nentropy = 0.993\nsamples = 20\nvalue = [11, 9]\nclass = STAY"),
#  Text(0.08986286745401113, 0.7752293577981652, "['income'] <= 24836.0\nentropy = 0.998\nsamples = 17\nvalue = [8, 9]\nclass = LEAVE"),
#  Text(0.0861495258236801, 0.7660550458715596, "['income'] <= 24747.0\nentropy = 0.946\nsamples = 11\nvalue = [7, 4]\nclass = STAY"),
#  Text(0.08317885251941526, 0.7568807339449541, "['income'] <= 24716.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = LEAVE"),
#  Text(0.08169351586728285, 0.7477064220183486, "['income'] <= 24690.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = STAY"),
#  Text(0.08020817921515043, 0.7385321100917431, "['income'] <= 24669.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = LEAVE"),
#  Text(0.07872284256301802, 0.7293577981651376, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY'),
#  Text(0.08169351586728285, 0.7293577981651376, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.08317885251941526, 0.7385321100917431, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.08466418917154768, 0.7477064220183486, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.08912019912794493, 0.7568807339449541, "['income'] <= 24804.5\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]\nclass = STAY"),
#  Text(0.08763486247581251, 0.7477064220183486, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = STAY'),
#  Text(0.09060553578007734, 0.7477064220183486, "['income'] <= 24816.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.08912019912794493, 0.7385321100917431, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.09209087243220976, 0.7385321100917431, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.09357620908434218, 0.7660550458715596, "['income'] <= 24964.0\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = LEAVE"),
#  Text(0.09209087243220976, 0.7568807339449541, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = LEAVE'),
#  Text(0.09506154573647459, 0.7568807339449541, "['income'] <= 24975.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.09357620908434218, 0.7477064220183486, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.09654688238860701, 0.7477064220183486, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.09283354075827596, 0.7752293577981652, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.09431887741040838, 0.7844036697247706, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.09580421406254079, 0.7935779816513762, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.09728955071467321, 0.8027522935779816, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.10174556067107046, 0.8119266055045872, "['income'] <= 25158.0\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]\nclass = STAY"),
#  Text(0.10026022401893804, 0.8027522935779816, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.10323089732320287, 0.8027522935779816, "['income'] <= 25168.0\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]\nclass = STAY"),
#  Text(0.10174556067107046, 0.7935779816513762, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.10471623397533529, 0.7935779816513762, "['income'] <= 25239.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = STAY"),
#  Text(0.10323089732320287, 0.7844036697247706, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.1062015706274677, 0.7844036697247706, "['income'] <= 25280.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.10471623397533529, 0.7752293577981652, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.10768690727960012, 0.7752293577981652, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.10174556067107046, 0.8211009174311926, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.06888248724264076, 0.9311926605504587, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.14793281677904602, 0.9587155963302753, "['income'] <= 27265.0\nentropy = 0.989\nsamples = 2394\nvalue = [1051, 1343]\nclass = LEAVE"),
#  Text(0.11845559800756013, 0.9495412844036697, "['income'] <= 27048.0\nentropy = 0.906\nsamples = 87\nvalue = [28, 59]\nclass = LEAVE"),
#  Text(0.11697026135542772, 0.9403669724770642, "['income'] <= 25556.0\nentropy = 0.93\nsamples = 81\nvalue = [28, 53]\nclass = LEAVE"),
#  Text(0.11251425139903047, 0.9311926605504587, "['income'] <= 25473.5\nentropy = 0.619\nsamples = 13\nvalue = [2, 11]\nclass = LEAVE"),
#  Text(0.11102891474689805, 0.9220183486238532, "['income'] <= 25429.5\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = LEAVE"),
#  Text(0.10954357809476564, 0.9128440366972477, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.11251425139903047, 0.9128440366972477, "['income'] <= 25440.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = STAY"),
#  Text(0.11102891474689805, 0.9036697247706422, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.11399958805116288, 0.9036697247706422, "['income'] <= 25456.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.11251425139903047, 0.8944954128440367, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.1154849247032953, 0.8944954128440367, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.11399958805116288, 0.9220183486238532, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = LEAVE'),
#  Text(0.12142627131182496, 0.9311926605504587, "['income'] <= 25630.5\nentropy = 0.96\nsamples = 68\nvalue = [26, 42]\nclass = LEAVE"),
#  Text(0.11994093465969255, 0.9220183486238532, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.12291160796395738, 0.9220183486238532, "['income'] <= 26999.0\nentropy = 0.937\nsamples = 65\nvalue = [23, 42]\nclass = LEAVE"),
#  Text(0.12142627131182496, 0.9128440366972477, "['income'] <= 26887.0\nentropy = 0.928\nsamples = 64\nvalue = [22, 42]\nclass = LEAVE"),
#  Text(0.11994093465969255, 0.9036697247706422, "['income'] <= 26877.0\nentropy = 0.948\nsamples = 60\nvalue = [22, 38]\nclass = LEAVE"),
#  Text(0.11845559800756013, 0.8944954128440367, "['income'] <= 26833.5\nentropy = 0.939\nsamples = 59\nvalue = [21, 38]\nclass = LEAVE"),
#  Text(0.11697026135542772, 0.8853211009174312, "['income'] <= 26758.0\nentropy = 0.959\nsamples = 55\nvalue = [21, 34]\nclass = LEAVE"),
#  Text(0.1154849247032953, 0.8761467889908257, "['income'] <= 25656.0\nentropy = 0.931\nsamples = 52\nvalue = [18, 34]\nclass = LEAVE"),
#  Text(0.11399958805116288, 0.8669724770642202, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.11697026135542772, 0.8669724770642202, "['income'] <= 25687.0\nentropy = 0.943\nsamples = 50\nvalue = [18, 32]\nclass = LEAVE"),
#  Text(0.1154849247032953, 0.8577981651376146, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.11845559800756013, 0.8577981651376146, "['income'] <= 25709.5\nentropy = 0.918\nsamples = 48\nvalue = [16, 32]\nclass = LEAVE"),
#  Text(0.11697026135542772, 0.8486238532110092, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.11994093465969255, 0.8486238532110092, "['income'] <= 25719.5\nentropy = 0.932\nsamples = 46\nvalue = [16, 30]\nclass = LEAVE"),
#  Text(0.11845559800756013, 0.8394495412844036, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.12142627131182496, 0.8394495412844036, "['income'] <= 26002.5\nentropy = 0.918\nsamples = 45\nvalue = [15, 30]\nclass = LEAVE"),
#  Text(0.1165989271923946, 0.8302752293577982, "['income'] <= 25944.0\nentropy = 0.722\nsamples = 15\nvalue = [3, 12]\nclass = LEAVE"),
#  Text(0.1151135905402622, 0.8211009174311926, "['income'] <= 25930.5\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]\nclass = LEAVE"),
#  Text(0.11362825388812978, 0.8119266055045872, "['income'] <= 25835.5\nentropy = 0.722\nsamples = 10\nvalue = [2, 8]\nclass = LEAVE"),
#  Text(0.11214291723599737, 0.8027522935779816, "['income'] <= 25807.5\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = LEAVE"),
#  Text(0.11065758058386495, 0.7935779816513762, "['income'] <= 25732.0\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = LEAVE"),
#  Text(0.10917224393173254, 0.7844036697247706, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY'),
#  Text(0.11214291723599737, 0.7844036697247706, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.11362825388812978, 0.7935779816513762, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.1151135905402622, 0.8027522935779816, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = LEAVE'),
#  Text(0.1165989271923946, 0.8119266055045872, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.11808426384452703, 0.8211009174311926, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = LEAVE'),
#  Text(0.12625361543125532, 0.8302752293577982, "['income'] <= 26712.0\nentropy = 0.971\nsamples = 30\nvalue = [12, 18]\nclass = LEAVE"),
#  Text(0.1247682787791229, 0.8211009174311926, "['income'] <= 26642.5\nentropy = 0.985\nsamples = 28\nvalue = [12, 16]\nclass = LEAVE"),
#  Text(0.12105493714879186, 0.8119266055045872, "['income'] <= 26394.5\nentropy = 0.954\nsamples = 24\nvalue = [9, 15]\nclass = LEAVE"),
#  Text(0.11808426384452703, 0.8027522935779816, "['income'] <= 26373.5\nentropy = 1.0\nsamples = 16\nvalue = [8, 8]\nclass = STAY"),
#  Text(0.1165989271923946, 0.7935779816513762, "['income'] <= 26284.5\nentropy = 0.985\nsamples = 14\nvalue = [6, 8]\nclass = LEAVE"),
#  Text(0.1151135905402622, 0.7844036697247706, "['income'] <= 26267.5\nentropy = 1.0\nsamples = 12\nvalue = [6, 6]\nclass = STAY"),
#  Text(0.11362825388812978, 0.7752293577981652, "['income'] <= 26011.0\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]\nclass = LEAVE"),
#  Text(0.11214291723599737, 0.7660550458715596, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.1151135905402622, 0.7660550458715596, "['income'] <= 26078.5\nentropy = 0.918\nsamples = 9\nvalue = [3, 6]\nclass = LEAVE"),
#  Text(0.11362825388812978, 0.7568807339449541, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.1165989271923946, 0.7568807339449541, "['income'] <= 26132.0\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]\nclass = LEAVE"),
#  Text(0.1151135905402622, 0.7477064220183486, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.11808426384452703, 0.7477064220183486, "['income'] <= 26190.0\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = LEAVE"),
#  Text(0.1165989271923946, 0.7385321100917431, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.11956960049665945, 0.7385321100917431, "['income'] <= 26194.0\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = STAY"),
#  Text(0.11808426384452703, 0.7293577981651376, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.12105493714879186, 0.7293577981651376, "['income'] <= 26219.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = LEAVE"),
#  Text(0.11956960049665945, 0.7201834862385321, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.12254027380092428, 0.7201834862385321, "['income'] <= 26253.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.12105493714879186, 0.7110091743119266, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.12402561045305668, 0.7110091743119266, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.1165989271923946, 0.7752293577981652, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.11808426384452703, 0.7844036697247706, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.11956960049665945, 0.7935779816513762, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.12402561045305668, 0.8027522935779816, "['income'] <= 26613.5\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]\nclass = LEAVE"),
#  Text(0.12254027380092428, 0.7935779816513762, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = LEAVE'),
#  Text(0.1255109471051891, 0.7935779816513762, "['income'] <= 26626.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.12402561045305668, 0.7844036697247706, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.12699628375732153, 0.7844036697247706, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.12848162040945393, 0.8119266055045872, "['income'] <= 26703.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = STAY"),
#  Text(0.12699628375732153, 0.8027522935779816, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.12996695706158634, 0.8027522935779816, "['income'] <= 26707.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.12848162040945393, 0.7935779816513762, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.13145229371371878, 0.7935779816513762, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.12773895208338773, 0.8211009174311926, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.11845559800756013, 0.8761467889908257, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.11994093465969255, 0.8853211009174312, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = LEAVE'),
#  Text(0.12142627131182496, 0.8944954128440367, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.12291160796395738, 0.9036697247706422, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = LEAVE'),
#  Text(0.1243969446160898, 0.9128440366972477, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.11994093465969255, 0.9403669724770642, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = LEAVE'),
#  Text(0.17741003555053192, 0.9495412844036697, "['income'] <= 27358.0\nentropy = 0.991\nsamples = 2307\nvalue = [1023, 1284]\nclass = LEAVE"),
#  Text(0.17592469889839948, 0.9403669724770642, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = STAY'),
#  Text(0.17889537220266433, 0.9403669724770642, "['income'] <= 27898.0\nentropy = 0.99\nsamples = 2302\nvalue = [1018, 1284]\nclass = LEAVE"),
#  Text(0.1340516328549505, 0.9311926605504587, "['income'] <= 27585.5\nentropy = 0.958\nsamples = 29\nvalue = [18, 11]\nclass = STAY"),
#  Text(0.13033829122461946, 0.9220183486238532, "['income'] <= 27482.5\nentropy = 0.98\nsamples = 12\nvalue = [5, 7]\nclass = LEAVE"),
#  Text(0.12736761792035461, 0.9128440366972477, "['income'] <= 27407.0\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = STAY"),
#  Text(0.1258822812682222, 0.9036697247706422, "['income'] <= 27391.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = LEAVE"),
#  Text(0.1243969446160898, 0.8944954128440367, "['income'] <= 27379.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.12291160796395738, 0.8853211009174312, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.1258822812682222, 0.8853211009174312, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.12736761792035461, 0.8944954128440367, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.12885295457248705, 0.9036697247706422, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.1333089645288843, 0.9128440366972477, "['income'] <= 27553.5\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = LEAVE"),
#  Text(0.13182362787675186, 0.9036697247706422, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.1347943011810167, 0.9036697247706422, "['income'] <= 27577.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.1333089645288843, 0.8944954128440367, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.13627963783314911, 0.8944954128440367, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.13776497448528152, 0.9220183486238532, "['income'] <= 27715.5\nentropy = 0.787\nsamples = 17\nvalue = [13, 4]\nclass = STAY"),
#  Text(0.13627963783314911, 0.9128440366972477, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = STAY'),
#  Text(0.13925031113741396, 0.9128440366972477, "['income'] <= 27741.5\nentropy = 0.946\nsamples = 11\nvalue = [7, 4]\nclass = STAY"),
#  Text(0.13776497448528152, 0.9036697247706422, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.14073564778954636, 0.9036697247706422, "['income'] <= 27754.5\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]\nclass = STAY"),
#  Text(0.13925031113741396, 0.8944954128440367, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.14222098444167877, 0.8944954128440367, "['income'] <= 27764.0\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = STAY"),
#  Text(0.14073564778954636, 0.8853211009174312, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.1437063210938112, 0.8853211009174312, "['income'] <= 27851.0\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]\nclass = STAY"),
#  Text(0.14222098444167877, 0.8761467889908257, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.14519165774594361, 0.8761467889908257, "['income'] <= 27870.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = STAY"),
#  Text(0.1437063210938112, 0.8669724770642202, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.14667699439807602, 0.8669724770642202, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.22373911155037815, 0.9311926605504587, "['income'] <= 29616.0\nentropy = 0.99\nsamples = 2273\nvalue = [1000, 1273]\nclass = LEAVE"),
#  Text(0.17554822557389985, 0.9220183486238532, "['income'] <= 29110.0\nentropy = 0.905\nsamples = 78\nvalue = [25, 53]\nclass = LEAVE"),
#  Text(0.1702567137506781, 0.9128440366972477, "['income'] <= 27917.0\nentropy = 0.948\nsamples = 60\nvalue = [22, 38]\nclass = LEAVE"),
#  Text(0.1687713770985457, 0.9036697247706422, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.17174205040281054, 0.9036697247706422, "['income'] <= 28920.5\nentropy = 0.962\nsamples = 57\nvalue = [22, 35]\nclass = LEAVE"),
#  Text(0.1656150367127643, 0.8944954128440367, "['income'] <= 28821.0\nentropy = 0.931\nsamples = 49\nvalue = [17, 32]\nclass = LEAVE"),
#  Text(0.1641297000606319, 0.8853211009174312, "['income'] <= 28431.5\nentropy = 0.962\nsamples = 44\nvalue = [17, 27]\nclass = LEAVE"),
#  Text(0.15484634598480432, 0.8761467889908257, "['income'] <= 28178.0\nentropy = 0.996\nsamples = 28\nvalue = [13, 15]\nclass = LEAVE"),
#  Text(0.14964766770234086, 0.8669724770642202, "['income'] <= 27936.5\nentropy = 0.89\nsamples = 13\nvalue = [4, 9]\nclass = LEAVE"),
#  Text(0.14816233105020843, 0.8577981651376146, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.15113300435447327, 0.8577981651376146, "['income'] <= 28159.0\nentropy = 0.811\nsamples = 12\nvalue = [3, 9]\nclass = LEAVE"),
#  Text(0.14964766770234086, 0.8486238532110092, "['income'] <= 28150.5\nentropy = 0.881\nsamples = 10\nvalue = [3, 7]\nclass = LEAVE"),
#  Text(0.14816233105020843, 0.8394495412844036, "['income'] <= 28107.5\nentropy = 0.764\nsamples = 9\nvalue = [2, 7]\nclass = LEAVE"),
#  Text(0.14667699439807602, 0.8302752293577982, "['income'] <= 28074.0\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = LEAVE"),
#  Text(0.14519165774594361, 0.8211009174311926, "['income'] <= 28027.0\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = LEAVE"),
#  Text(0.1437063210938112, 0.8119266055045872, "['income'] <= 27981.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.14222098444167877, 0.8027522935779816, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.14519165774594361, 0.8027522935779816, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.14667699439807602, 0.8119266055045872, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.14816233105020843, 0.8211009174311926, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
# ...
#  Text(0.32937340261036313, 0.7018348623853211, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.33234407591462795, 0.7018348623853211, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.33382941256676035, 0.7110091743119266, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.33828542252315763, 0.7201834862385321, "['income'] <= 38993.5\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]\nclass = STAY"),
#  Text(0.3368000858710252, 0.7110091743119266, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.33977075917529004, 0.7110091743119266, "['income'] <= 39001.5\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = STAY"),
#  Text(0.33828542252315763, 0.7018348623853211, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.34125609582742245, 0.7018348623853211, "['income'] <= 39026.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]\nclass = STAY"),
#  Text(0.33977075917529004, 0.6926605504587156, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.34274143247955485, 0.6926605504587156, "['income'] <= 39133.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = STAY"),
#  Text(0.34125609582742245, 0.6834862385321101, "['income'] <= 39115.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = STAY"),
#  Text(0.33977075917529004, 0.6743119266055045, "['income'] <= 39074.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = STAY"),
#  Text(0.33828542252315763, 0.6651376146788991, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY'),
#  Text(0.34125609582742245, 0.6651376146788991, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.34274143247955485, 0.6743119266055045, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.34422676913168726, 0.6834862385321101, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.31514666248915735, 0.7844036697247706, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = LEAVE'),
#  Text(0.32937340261036313, 0.7935779816513762, "['income'] <= 39563.0\nentropy = 0.469\nsamples = 10\nvalue = [9, 1]\nclass = STAY"),
#  Text(0.3278880659582307, 0.7844036697247706, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = STAY'),
#  Text(0.33085873926249554, 0.7844036697247706, "['income'] <= 39592.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = STAY"),
#  Text(0.32937340261036313, 0.7752293577981652, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.33234407591462795, 0.7752293577981652, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.35908013565301145, 0.8027522935779816, "['income'] <= 39641.0\nentropy = 0.983\nsamples = 118\nvalue = [50, 68]\nclass = LEAVE"),
#  Text(0.35759479900087904, 0.7935779816513762, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.36056547230514385, 0.7935779816513762, "['income'] <= 39703.5\nentropy = 0.988\nsamples = 115\nvalue = [50, 65]\nclass = LEAVE"),
#  Text(0.3568521306748128, 0.7844036697247706, "['income'] <= 39690.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = STAY"),
#  Text(0.3553667940226804, 0.7752293577981652, "['income'] <= 39671.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.353881457370548, 0.7660550458715596, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.3568521306748128, 0.7660550458715596, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.3583374673269452, 0.7752293577981652, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.3642788139354749, 0.7844036697247706, "['income'] <= 42477.0\nentropy = 0.983\nsamples = 111\nvalue = [47, 64]\nclass = LEAVE"),
#  Text(0.3627934772833425, 0.7752293577981652, "['income'] <= 42302.0\nentropy = 0.981\nsamples = 110\nvalue = [46, 64]\nclass = LEAVE"),
#  Text(0.3598228039790776, 0.7660550458715596, "['income'] <= 42277.5\nentropy = 0.987\nsamples = 104\nvalue = [45, 59]\nclass = LEAVE"),
#  Text(0.3583374673269452, 0.7568807339449541, "['income'] <= 42239.0\nentropy = 0.985\nsamples = 103\nvalue = [44, 59]\nclass = LEAVE"),
#  Text(0.3568521306748128, 0.7477064220183486, "['income'] <= 42099.0\nentropy = 0.988\nsamples = 101\nvalue = [44, 57]\nclass = LEAVE"),
#  Text(0.35313878904448176, 0.7385321100917431, "['income'] <= 41799.5\nentropy = 0.979\nsamples = 94\nvalue = [39, 55]\nclass = LEAVE"),
#  Text(0.35016811574021695, 0.7293577981651376, "['income'] <= 41764.0\nentropy = 0.989\nsamples = 82\nvalue = [36, 46]\nclass = LEAVE"),
#  Text(0.34868277908808454, 0.7201834862385321, "['income'] <= 39729.5\nentropy = 0.987\nsamples = 81\nvalue = [35, 46]\nclass = LEAVE"),
#  Text(0.34571210578381967, 0.7110091743119266, "['income'] <= 39709.0\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = LEAVE"),
#  Text(0.34422676913168726, 0.7018348623853211, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY'),
#  Text(0.34719744243595213, 0.7018348623853211, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.35165345239234935, 0.7110091743119266, "['income'] <= 39754.0\nentropy = 0.992\nsamples = 76\nvalue = [34, 42]\nclass = LEAVE"),
#  Text(0.35016811574021695, 0.7018348623853211, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.35313878904448176, 0.7018348623853211, "['income'] <= 39787.0\nentropy = 0.99\nsamples = 75\nvalue = [33, 42]\nclass = LEAVE"),
#  Text(0.35165345239234935, 0.6926605504587156, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.35462412569661417, 0.6926605504587156, "['income'] <= 39816.5\nentropy = 0.992\nsamples = 74\nvalue = [33, 41]\nclass = LEAVE"),
#  Text(0.35313878904448176, 0.6834862385321101, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.3561094623487466, 0.6834862385321101, "['income'] <= 39853.5\nentropy = 0.989\nsamples = 73\nvalue = [32, 41]\nclass = LEAVE"),
#  Text(0.35462412569661417, 0.6743119266055045, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.35759479900087904, 0.6743119266055045, "['income'] <= 39885.5\nentropy = 0.991\nsamples = 72\nvalue = [32, 40]\nclass = LEAVE"),
#  Text(0.3561094623487466, 0.6651376146788991, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.35908013565301145, 0.6651376146788991, "['income'] <= 40347.5\nentropy = 0.985\nsamples = 70\nvalue = [30, 40]\nclass = LEAVE"),
#  Text(0.3561094623487466, 0.6559633027522935, "['income'] <= 40319.5\nentropy = 0.918\nsamples = 24\nvalue = [8, 16]\nclass = LEAVE"),
#  Text(0.35462412569661417, 0.6467889908256881, "['income'] <= 40293.0\nentropy = 0.959\nsamples = 21\nvalue = [8, 13]\nclass = LEAVE"),
#  Text(0.35313878904448176, 0.6376146788990825, "['income'] <= 40262.0\nentropy = 0.934\nsamples = 20\nvalue = [7, 13]\nclass = LEAVE"),
#  Text(0.35165345239234935, 0.6284403669724771, "['income'] <= 40259.0\nentropy = 0.977\nsamples = 17\nvalue = [7, 10]\nclass = LEAVE"),
#  Text(0.35016811574021695, 0.6192660550458715, "['income'] <= 39983.0\nentropy = 0.954\nsamples = 16\nvalue = [6, 10]\nclass = LEAVE"),
#  Text(0.34719744243595213, 0.6100917431192661, "['income'] <= 39910.5\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = LEAVE"),
#  Text(0.34571210578381967, 0.6009174311926605, "['income'] <= 39890.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.34422676913168726, 0.591743119266055, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.34719744243595213, 0.591743119266055, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.34868277908808454, 0.6009174311926605, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.35313878904448176, 0.6100917431192661, "['income'] <= 40054.5\nentropy = 0.994\nsamples = 11\nvalue = [5, 6]\nclass = LEAVE"),
#  Text(0.35165345239234935, 0.6009174311926605, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.35462412569661417, 0.6009174311926605, "['income'] <= 40199.5\nentropy = 0.918\nsamples = 9\nvalue = [3, 6]\nclass = LEAVE"),
#  Text(0.35313878904448176, 0.591743119266055, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.3561094623487466, 0.591743119266055, "['income'] <= 40218.5\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]\nclass = STAY"),
#  Text(0.35462412569661417, 0.5825688073394495, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.35759479900087904, 0.5825688073394495, "['income'] <= 40244.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = LEAVE"),
#  Text(0.3561094623487466, 0.573394495412844, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.35908013565301145, 0.573394495412844, "['income'] <= 40251.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.35759479900087904, 0.5642201834862385, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.36056547230514385, 0.5642201834862385, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.35313878904448176, 0.6192660550458715, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.35462412569661417, 0.6284403669724771, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.3561094623487466, 0.6376146788990825, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.35759479900087904, 0.6467889908256881, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.36205080895727626, 0.6559633027522935, "['income'] <= 40399.0\nentropy = 0.999\nsamples = 46\nvalue = [22, 24]\nclass = LEAVE"),
#  Text(0.36056547230514385, 0.6467889908256881, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.36353614560940867, 0.6467889908256881, "['income'] <= 40431.0\nentropy = 0.994\nsamples = 44\nvalue = [20, 24]\nclass = LEAVE"),
#  Text(0.36205080895727626, 0.6376146788990825, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.3650214822615411, 0.6376146788990825, "['income'] <= 40432.5\nentropy = 0.996\nsamples = 43\nvalue = [20, 23]\nclass = LEAVE"),
#  Text(0.36353614560940867, 0.6284403669724771, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.36650681891367354, 0.6284403669724771, "['income'] <= 40716.5\nentropy = 0.993\nsamples = 42\nvalue = [19, 23]\nclass = LEAVE"),
#  Text(0.36353614560940867, 0.6192660550458715, "['income'] <= 40516.0\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = LEAVE"),
#  Text(0.36205080895727626, 0.6100917431192661, "['income'] <= 40458.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY"),
#  Text(0.36056547230514385, 0.6009174311926605, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.36353614560940867, 0.6009174311926605, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.3650214822615411, 0.6100917431192661, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.36947749221793835, 0.6192660550458715, "['income'] <= 40763.5\nentropy = 0.999\nsamples = 37\nvalue = [18, 19]\nclass = LEAVE"),
#  Text(0.36799215556580595, 0.6100917431192661, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.37096282887007076, 0.6100917431192661, "['income'] <= 40786.5\nentropy = 0.995\nsamples = 35\nvalue = [16, 19]\nclass = LEAVE"),
#  Text(0.36947749221793835, 0.6009174311926605, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.37244816552220317, 0.6009174311926605, "['income'] <= 40809.0\nentropy = 0.999\nsamples = 33\nvalue = [16, 17]\nclass = LEAVE"),
#  Text(0.37096282887007076, 0.591743119266055, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.3739335021743356, 0.591743119266055, "['income'] <= 40840.0\nentropy = 0.997\nsamples = 32\nvalue = [15, 17]\nclass = LEAVE"),
#  Text(0.37244816552220317, 0.5825688073394495, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.375418838826468, 0.5825688073394495, "['income'] <= 40879.5\nentropy = 1.0\nsamples = 30\nvalue = [15, 15]\nclass = STAY"),
#  Text(0.3739335021743356, 0.573394495412844, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.37690417547860045, 0.573394495412844, "['income'] <= 40964.5\nentropy = 0.996\nsamples = 28\nvalue = [13, 15]\nclass = LEAVE"),
#  Text(0.375418838826468, 0.5642201834862385, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.37838951213073285, 0.5642201834862385, "['income'] <= 41002.5\nentropy = 0.999\nsamples = 25\nvalue = [13, 12]\nclass = STAY"),
#  Text(0.37690417547860045, 0.555045871559633, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = STAY'),
#  Text(0.37987484878286526, 0.555045871559633, "['income'] <= 41028.5\nentropy = 0.994\nsamples = 22\nvalue = [10, 12]\nclass = LEAVE"),
#  Text(0.37838951213073285, 0.5458715596330275, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.38136018543499767, 0.5458715596330275, "['income'] <= 41053.5\nentropy = 0.998\nsamples = 21\nvalue = [10, 11]\nclass = LEAVE"),
#  Text(0.37987484878286526, 0.536697247706422, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.3828455220871301, 0.536697247706422, "['income'] <= 41073.5\nentropy = 0.982\nsamples = 19\nvalue = [8, 11]\nclass = LEAVE"),
#  Text(0.38136018543499767, 0.5275229357798165, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.3843308587392625, 0.5275229357798165, "['income'] <= 41100.0\nentropy = 0.991\nsamples = 18\nvalue = [8, 10]\nclass = LEAVE"),
#  Text(0.3828455220871301, 0.518348623853211, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.3858161953913949, 0.518348623853211, "['income'] <= 41138.5\nentropy = 0.977\nsamples = 17\nvalue = [7, 10]\nclass = LEAVE"),
#  Text(0.3843308587392625, 0.5091743119266054, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = LEAVE'),
#  Text(0.38730153204352735, 0.5091743119266054, "['income'] <= 41174.5\nentropy = 0.997\nsamples = 15\nvalue = [7, 8]\nclass = LEAVE"),
#  Text(0.3858161953913949, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = STAY'),
#  Text(0.38878686869565976, 0.5, "['income'] <= 41233.0\nentropy = 0.961\nsamples = 13\nvalue = [5, 8]\nclass = LEAVE"),
#  Text(0.38730153204352735, 0.4908256880733945, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.39027220534779217, 0.4908256880733945, "['income'] <= 41292.5\nentropy = 0.98\nsamples = 12\nvalue = [5, 7]\nclass = LEAVE"),
#  Text(0.38878686869565976, 0.481651376146789, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.3917575419999246, 0.481651376146789, "['income'] <= 41499.0\nentropy = 0.946\nsamples = 11\nvalue = [4, 7]\nclass = LEAVE"),
#  Text(0.38878686869565976, 0.4724770642201835, "['income'] <= 41297.0\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = LEAVE"),
#  Text(0.38730153204352735, 0.463302752293578, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = STAY'),
#  Text(0.39027220534779217, 0.463302752293578, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = LEAVE'),
#  Text(0.3947282153041894, 0.4724770642201835, "['income'] <= 41571.5\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]\nclass = STAY"),
#  Text(0.393242878652057, 0.463302752293578, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.3962135519563218, 0.463302752293578, "['income'] <= 41592.0\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = LEAVE"),
#  Text(0.3947282153041894, 0.4541284403669725, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  Text(0.39769888860845426, 0.4541284403669725, "['income'] <= 41609.0\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = STAY"),
#  Text(0.3962135519563218, 0.44495412844036697, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = STAY'),
#  Text(0.39918422526058667, 0.44495412844036697, "['income'] <= 41653.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = LEAVE"),
#  Text(0.39769888860845426, 0.43577981651376146, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = LEAVE'),
#  ...]

# %% [markdown]
# Explanation of code:
#
# - `plot_tree()`: Function from scikit-learn to visualize the decision tree
# - `money_tree`: The fitted decision tree model to be visualized
# - `feature_names=[['income']]`: Labels the feature as `income` in the tree diagram
# - `class_names=['STAY', 'LEAVE']`: Specifies the names for the target classes in the visualization
# - `filled=True`: Colorizes the nodes based on the majority class at each node

# %% [markdown]
# This plot is a bit confusing!  Here is an interpretive guide.
#
# 1. **Root Node (Top)**:
#    - Split: income <= 99993.0
#    - Samples: 4994
#    - Initial prediction: LEAVE
#
# 2. **Second Level**:
#    - Left Branch (income <= 20181.0):
#      - Samples: 3303
#      - Prediction: LEAVE
#    - Right Branch (20181.0 < income <= 159576.0):
#      - Samples: 1691
#      - Prediction: STAY
#
# 3. **Third Level (Leaf Nodes)**:
#    - Far Left (income <= 20181.0):
#      - Samples: 8
#      - Prediction: LEAVE (high certainty, entropy = 0.0)
#    - Middle Left (20181.0 < income <= 99993.0):
#      - Samples: 3295
#      - Prediction: LEAVE (with uncertainty, entropy = 0.991)
#    - Middle Right (99993.0 < income <= 159576.0):
#      - Samples: 1680
#      - Prediction: STAY (with uncertainty, entropy = 0.977)
#    - Far Right (income > 159576.0):
#      - Samples: 11
#      - Prediction: STAY (high certainty, entropy = 0.0)

# %% [markdown]
# ## Check Accuracy
#
# What is the accuracy of the money_tree?

# %%
# 1. Generate predictions from the model for the training data
pred = money_tree.predict(X = mtc_clean[['income']])

# %% [markdown]
# Explanation of code:
#
# - `money_tree.predict()`: Method to make predictions using the trained decision tree model
# - `X = mtc_clean[['income']]`: Input data for prediction, using only the `income` column from the DataFrame
# - Output: Returns an array of predicted class labels ('STAY' or 'LEAVE') for each row in the input data

# %%
# 2. Calculate accuracy as the proportion of correct predictions

# Your code goes here

sum(pred == mtc_clean['leave']) / len(pred)
# Out:
# 0.8956748097717261

# %% [markdown]
# So, this is better than the accuracy of the majority class classifier, which was our benchmark.  Success!
#
# Would a more complicated model have better performance measured in terms of accuracy?

# %% [markdown]
# ## Overfitting
#
# Refit the tree, only this time leave out the `max_depth` argument.  This will allow the tree to fit as complicated a model as possible.

# %%
# Your code goes here

money_tree = DecisionTreeClassifier(criterion = "entropy")

money_tree = money_tree.fit(X = mtc_clean[['income']],
                            y = mtc_clean['leave'])

pred = money_tree.predict(X = mtc_clean[['income']])

sum(pred == mtc_clean['leave']) / len(mtc_clean)
# Out:
# 0.9881858229875851

# %%
plot_tree(money_tree,
          feature_names=[['income']],
          class_names=['stay', 'leave'],
          filled=True)
# Out:
# [Text(0.6702882659988018, 0.9961240310077519, "['income'] <= 99993.0\nentropy = 1.0\nsamples = 4994\nvalue = [2468, 2526]\nclass = leave"),
#  Text(0.558612117580282, 0.9883720930232558, "['income'] <= 20181.0\nentropy = 0.991\nsamples = 3303\nvalue = [1468, 1835]\nclass = leave"),
#  Text(0.5573289843292746, 0.9806201550387597, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = leave'),
#  Text(0.5598952508312892, 0.9806201550387597, "['income'] <= 20351.0\nentropy = 0.991\nsamples = 3295\nvalue = [1468, 1827]\nclass = leave"),
#  Text(0.5245503394451976, 0.9728682170542635, "['income'] <= 20247.5\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]\nclass = stay"),
#  Text(0.5232672061941903, 0.9651162790697675, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = stay'),
#  Text(0.525833472696205, 0.9651162790697675, "['income'] <= 20312.0\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = stay"),
#  Text(0.5245503394451976, 0.9573643410852714, "['income'] <= 20284.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = leave"),
#  Text(0.5232672061941903, 0.9496124031007752, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.525833472696205, 0.9496124031007752, "['income'] <= 20300.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.5245503394451976, 0.9418604651162791, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.5271166059472122, 0.9418604651162791, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.5271166059472122, 0.9573643410852714, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = stay'),
#  Text(0.5952401622173807, 0.9728682170542635, "['income'] <= 99959.0\nentropy = 0.991\nsamples = 3284\nvalue = [1459, 1825]\nclass = leave"),
#  Text(0.5939570289663735, 0.9651162790697675, "['income'] <= 99822.0\nentropy = 0.991\nsamples = 3281\nvalue = [1459, 1822]\nclass = leave"),
#  Text(0.5725323101273246, 0.9573643410852714, "['income'] <= 99568.0\nentropy = 0.991\nsamples = 3276\nvalue = [1455, 1821]\nclass = leave"),
#  Text(0.5712491768763173, 0.9496124031007752, "['income'] <= 89446.0\nentropy = 0.991\nsamples = 3271\nvalue = [1455, 1816]\nclass = leave"),
#  Text(0.5296828724492268, 0.9418604651162791, "['income'] <= 89260.0\nentropy = 0.993\nsamples = 2939\nvalue = [1321, 1618]\nclass = leave"),
#  Text(0.5283997391982196, 0.9341085271317829, "['income'] <= 20379.0\nentropy = 0.992\nsamples = 2936\nvalue = [1318, 1618]\nclass = leave"),
#  Text(0.5271166059472122, 0.9263565891472868, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.5296828724492268, 0.9263565891472868, "['income'] <= 87001.0\nentropy = 0.993\nsamples = 2934\nvalue = [1318, 1616]\nclass = leave"),
#  Text(0.5119499614823244, 0.9186046511627907, "['income'] <= 86938.0\nentropy = 0.992\nsamples = 2865\nvalue = [1282, 1583]\nclass = leave"),
#  Text(0.5106668282313171, 0.9108527131782945, "['income'] <= 86905.0\nentropy = 0.992\nsamples = 2859\nvalue = [1282, 1577]\nclass = leave"),
#  Text(0.5093836949803098, 0.9031007751937985, "['income'] <= 86817.5\nentropy = 0.992\nsamples = 2856\nvalue = [1279, 1577]\nclass = leave"),
#  Text(0.5081005617293025, 0.8953488372093024, "['income'] <= 86656.5\nentropy = 0.992\nsamples = 2851\nvalue = [1279, 1572]\nclass = leave"),
#  Text(0.5068174284782953, 0.8875968992248062, "['income'] <= 86601.5\nentropy = 0.992\nsamples = 2848\nvalue = [1276, 1572]\nclass = leave"),
#  Text(0.5055342952272879, 0.8798449612403101, "['income'] <= 86543.0\nentropy = 0.992\nsamples = 2846\nvalue = [1276, 1570]\nclass = leave"),
#  Text(0.5042511619762806, 0.872093023255814, "['income'] <= 86391.5\nentropy = 0.992\nsamples = 2844\nvalue = [1274, 1570]\nclass = leave"),
#  Text(0.5029680287252734, 0.8643410852713178, "['income'] <= 86180.0\nentropy = 0.992\nsamples = 2842\nvalue = [1274, 1568]\nclass = leave"),
#  Text(0.4715119982008663, 0.8565891472868217, "['income'] <= 85779.5\nentropy = 0.992\nsamples = 2837\nvalue = [1270, 1567]\nclass = leave"),
#  Text(0.4124493369050742, 0.8488372093023255, "['income'] <= 85161.0\nentropy = 0.992\nsamples = 2827\nvalue = [1268, 1559]\nclass = leave"),
#  Text(0.2994565473175192, 0.8410852713178295, "['income'] <= 81352.0\nentropy = 0.992\nsamples = 2811\nvalue = [1257, 1554]\nclass = leave"),
#  Text(0.08646269230885811, 0.8333333333333334, "['income'] <= 81090.5\nentropy = 0.993\nsamples = 2685\nvalue = [1211, 1474]\nclass = leave"),
#  Text(0.08135141675256245, 0.8255813953488372, "['income'] <= 80824.5\nentropy = 0.993\nsamples = 2673\nvalue = [1202, 1471]\nclass = leave"),
#  Text(0.07878515025054784, 0.8178294573643411, "['income'] <= 80761.5\nentropy = 0.993\nsamples = 2666\nvalue = [1201, 1465]\nclass = leave"),
#  Text(0.07750201699954054, 0.810077519379845, "['income'] <= 80741.5\nentropy = 0.993\nsamples = 2662\nvalue = [1197, 1465]\nclass = leave"),
#  Text(0.07621888374853324, 0.8023255813953488, "['income'] <= 80663.5\nentropy = 0.993\nsamples = 2660\nvalue = [1197, 1463]\nclass = leave"),
#  Text(0.07493575049752593, 0.7945736434108527, "['income'] <= 80308.0\nentropy = 0.993\nsamples = 2658\nvalue = [1195, 1463]\nclass = leave"),
#  Text(0.05701439987889079, 0.7868217054263565, "['income'] <= 80216.0\nentropy = 0.992\nsamples = 2647\nvalue = [1188, 1459]\nclass = leave"),
#  Text(0.05573126662788349, 0.7790697674418605, "['income'] <= 80124.0\nentropy = 0.993\nsamples = 2641\nvalue = [1188, 1453]\nclass = leave"),
#  Text(0.054448133376876186, 0.7713178294573644, "['income'] <= 21427.5\nentropy = 0.993\nsamples = 2639\nvalue = [1186, 1453]\nclass = leave"),
#  Text(0.02245483189262781, 0.7635658914728682, "['income'] <= 21271.5\nentropy = 0.998\nsamples = 59\nvalue = [31, 28]\nclass = stay"),
#  Text(0.021171698641620506, 0.7558139534883721, "['income'] <= 21230.0\nentropy = 0.999\nsamples = 54\nvalue = [26, 28]\nclass = leave"),
#  Text(0.019888565390613202, 0.748062015503876, "['income'] <= 21221.5\nentropy = 1.0\nsamples = 53\nvalue = [26, 27]\nclass = leave"),
#  Text(0.0186054321396059, 0.7403100775193798, "['income'] <= 21213.5\nentropy = 0.999\nsamples = 52\nvalue = [25, 27]\nclass = leave"),
#  Text(0.017322298888598597, 0.7325581395348837, "['income'] <= 21190.5\nentropy = 1.0\nsamples = 51\nvalue = [25, 26]\nclass = leave"),
#  Text(0.016039165637591293, 0.7248062015503876, "['income'] <= 20982.0\nentropy = 0.997\nsamples = 49\nvalue = [23, 26]\nclass = leave"),
#  Text(0.013472899135576687, 0.7170542635658915, "['income'] <= 20812.0\nentropy = 0.998\nsamples = 34\nvalue = [18, 16]\nclass = stay"),
#  Text(0.012189765884569383, 0.7093023255813954, "['income'] <= 20777.5\nentropy = 0.992\nsamples = 29\nvalue = [13, 16]\nclass = leave"),
#  Text(0.010906632633562079, 0.7015503875968992, "['income'] <= 20746.5\nentropy = 1.0\nsamples = 26\nvalue = [13, 13]\nclass = stay"),
#  Text(0.009623499382554777, 0.6937984496124031, "['income'] <= 20737.0\nentropy = 0.988\nsamples = 23\nvalue = [10, 13]\nclass = leave"),
#  Text(0.008340366131547473, 0.686046511627907, "['income'] <= 20677.0\nentropy = 0.994\nsamples = 22\nvalue = [10, 12]\nclass = leave"),
#  Text(0.0051325330040292135, 0.6782945736434108, "['income'] <= 20392.5\nentropy = 0.964\nsamples = 18\nvalue = [7, 11]\nclass = leave"),
#  Text(0.0025662665020146067, 0.6705426356589147, "['income'] <= 20386.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = stay"),
#  Text(0.0012831332510073034, 0.6627906976744186, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay'),
#  Text(0.0038493997530219103, 0.6627906976744186, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.007698799506043821, 0.6705426356589147, "['income'] <= 20463.0\nentropy = 0.918\nsamples = 15\nvalue = [5, 10]\nclass = leave"),
#  Text(0.0064156662550365175, 0.6627906976744186, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.008981932757051125, 0.6627906976744186, "['income'] <= 20507.5\nentropy = 0.994\nsamples = 11\nvalue = [5, 6]\nclass = leave"),
#  Text(0.007698799506043821, 0.6550387596899225, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.010265066008058427, 0.6550387596899225, "['income'] <= 20580.5\nentropy = 0.918\nsamples = 9\nvalue = [3, 6]\nclass = leave"),
#  Text(0.007698799506043821, 0.6472868217054264, "['income'] <= 20534.0\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = stay"),
#  Text(0.0064156662550365175, 0.6395348837209303, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.008981932757051125, 0.6395348837209303, "['income'] <= 20553.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = stay"),
#  Text(0.007698799506043821, 0.6317829457364341, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.010265066008058427, 0.6317829457364341, "['income'] <= 20566.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.008981932757051125, 0.624031007751938, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.011548199259065731, 0.624031007751938, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.012831332510073035, 0.6472868217054264, "['income'] <= 20606.5\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = leave"),
#  Text(0.011548199259065731, 0.6395348837209303, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.014114465761080337, 0.6395348837209303, "['income'] <= 20627.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.012831332510073035, 0.6317829457364341, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.015397599012087641, 0.6317829457364341, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.011548199259065731, 0.6782945736434108, "['income'] <= 20732.0\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = stay"),
#  Text(0.010265066008058427, 0.6705426356589147, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.012831332510073035, 0.6705426356589147, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay'),
#  Text(0.010906632633562079, 0.686046511627907, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.012189765884569383, 0.6937984496124031, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.013472899135576687, 0.7015503875968992, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.01475603238658399, 0.7093023255813954, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = stay'),
#  Text(0.0186054321396059, 0.7170542635658915, "['income'] <= 21036.5\nentropy = 0.918\nsamples = 15\nvalue = [5, 10]\nclass = leave"),
#  Text(0.017322298888598597, 0.7093023255813954, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.019888565390613202, 0.7093023255813954, "['income'] <= 21068.5\nentropy = 0.994\nsamples = 11\nvalue = [5, 6]\nclass = leave"),
#  Text(0.0186054321396059, 0.7015503875968992, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.021171698641620506, 0.7015503875968992, "['income'] <= 21098.0\nentropy = 0.918\nsamples = 9\nvalue = [3, 6]\nclass = leave"),
#  Text(0.019888565390613202, 0.6937984496124031, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.02245483189262781, 0.6937984496124031, "['income'] <= 21109.5\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]\nclass = leave"),
#  Text(0.021171698641620506, 0.686046511627907, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.023737965143635114, 0.686046511627907, "['income'] <= 21114.0\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = leave"),
#  Text(0.02245483189262781, 0.6782945736434108, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.025021098394642418, 0.6782945736434108, "['income'] <= 21125.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = leave"),
#  Text(0.023737965143635114, 0.6705426356589147, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.026304231645649722, 0.6705426356589147, "['income'] <= 21177.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = leave"),
#  Text(0.025021098394642418, 0.6627906976744186, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.027587364896657026, 0.6627906976744186, "['income'] <= 21183.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.026304231645649722, 0.6550387596899225, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.028870498147664327, 0.6550387596899225, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.0186054321396059, 0.7248062015503876, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.019888565390613202, 0.7325581395348837, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.021171698641620506, 0.7403100775193798, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.02245483189262781, 0.748062015503876, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.023737965143635114, 0.7558139534883721, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = stay'),
#  Text(0.08644143486112456, 0.7635658914728682, "['income'] <= 21623.5\nentropy = 0.992\nsamples = 2580\nvalue = [1155, 1425]\nclass = leave"),
#  Text(0.08387516835910995, 0.7558139534883721, "['income'] <= 21501.5\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]\nclass = leave"),
#  Text(0.08259203510810265, 0.748062015503876, "['income'] <= 21485.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = leave"),
#  Text(0.08130890185709534, 0.7403100775193798, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.08387516835910995, 0.7403100775193798, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.08515830161011725, 0.748062015503876, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.08900770136313917, 0.7558139534883721, "['income'] <= 21664.5\nentropy = 0.992\nsamples = 2572\nvalue = [1154, 1418]\nclass = leave"),
#  Text(0.08772456811213186, 0.748062015503876, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.09029083461414647, 0.748062015503876, "['income'] <= 21790.5\nentropy = 0.992\nsamples = 2569\nvalue = [1151, 1418]\nclass = leave"),
#  Text(0.08772456811213186, 0.7403100775193798, "['income'] <= 21707.0\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]\nclass = leave"),
#  Text(0.08644143486112456, 0.7325581395348837, "['income'] <= 21684.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.08515830161011725, 0.7248062015503876, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.08772456811213186, 0.7248062015503876, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.08900770136313917, 0.7325581395348837, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = leave'),
#  Text(0.09285710111616108, 0.7403100775193798, "['income'] <= 21851.5\nentropy = 0.992\nsamples = 2562\nvalue = [1150, 1412]\nclass = leave"),
#  Text(0.09157396786515377, 0.7325581395348837, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = stay'),
#  Text(0.09414023436716838, 0.7325581395348837, "['income'] <= 21875.5\nentropy = 0.992\nsamples = 2556\nvalue = [1144, 1412]\nclass = leave"),
#  Text(0.09285710111616108, 0.7248062015503876, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.09542336761817569, 0.7248062015503876, "['income'] <= 21898.0\nentropy = 0.992\nsamples = 2553\nvalue = [1144, 1409]\nclass = leave"),
#  Text(0.09414023436716838, 0.7170542635658915, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.09670650086918298, 0.7170542635658915, "['income'] <= 22793.5\nentropy = 0.992\nsamples = 2551\nvalue = [1142, 1409]\nclass = leave"),
#  Text(0.04811749691277388, 0.7093023255813954, "['income'] <= 22640.0\nentropy = 0.918\nsamples = 63\nvalue = [21, 42]\nclass = leave"),
#  Text(0.04490966378525562, 0.7015503875968992, "['income'] <= 22524.0\nentropy = 0.968\nsamples = 48\nvalue = [19, 29]\nclass = leave"),
#  Text(0.04234339728324101, 0.6937984496124031, "['income'] <= 22435.0\nentropy = 0.926\nsamples = 41\nvalue = [14, 27]\nclass = leave"),
#  Text(0.04106026403223371, 0.686046511627907, "['income'] <= 22415.0\nentropy = 0.971\nsamples = 35\nvalue = [14, 21]\nclass = leave"),
#  Text(0.039777130781226404, 0.6782945736434108, "['income'] <= 22387.5\nentropy = 0.946\nsamples = 33\nvalue = [12, 21]\nclass = leave"),
#  Text(0.03849399753021911, 0.6705426356589147, "['income'] <= 22349.5\nentropy = 0.971\nsamples = 30\nvalue = [12, 18]\nclass = leave"),
#  Text(0.0372108642792118, 0.6627906976744186, "['income'] <= 21964.0\nentropy = 0.918\nsamples = 27\nvalue = [9, 18]\nclass = leave"),
#  Text(0.031436764649678935, 0.6550387596899225, "['income'] <= 21907.5\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = stay"),
#  Text(0.03015363139867163, 0.6472868217054264, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.03271989790068624, 0.6472868217054264, "['income'] <= 21932.0\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]\nclass = stay"),
#  Text(0.031436764649678935, 0.6395348837209303, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.03400303115169354, 0.6395348837209303, "['income'] <= 21942.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = stay"),
#  Text(0.03271989790068624, 0.6317829457364341, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.03528616440270085, 0.6317829457364341, "['income'] <= 21951.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = stay"),
#  Text(0.03400303115169354, 0.624031007751938, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.03656929765370815, 0.624031007751938, "['income'] <= 21958.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.03528616440270085, 0.6162790697674418, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.037852430904715455, 0.6162790697674418, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.042984963908744664, 0.6550387596899225, "['income'] <= 22195.5\nentropy = 0.811\nsamples = 20\nvalue = [5, 15]\nclass = leave"),
#  Text(0.040418697406730056, 0.6472868217054264, "['income'] <= 22098.5\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]\nclass = leave"),
#  Text(0.03913556415572276, 0.6395348837209303, "['income'] <= 22078.0\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = leave"),
#  Text(0.037852430904715455, 0.6317829457364341, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.040418697406730056, 0.6317829457364341, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.04170183065773736, 0.6395348837209303, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = leave'),
#  Text(0.04555123041075927, 0.6472868217054264, "['income'] <= 22212.0\nentropy = 0.991\nsamples = 9\nvalue = [4, 5]\nclass = leave"),
#  Text(0.04426809715975197, 0.6395348837209303, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.046834363661766576, 0.6395348837209303, "['income'] <= 22262.5\nentropy = 0.954\nsamples = 8\nvalue = [3, 5]\nclass = leave"),
#  Text(0.04426809715975197, 0.6317829457364341, "['income'] <= 22236.5\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = leave"),
#  Text(0.042984963908744664, 0.624031007751938, "['income'] <= 22227.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.04170183065773736, 0.6162790697674418, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.04426809715975197, 0.6162790697674418, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.04555123041075927, 0.624031007751938, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.049400630163781184, 0.6317829457364341, "['income'] <= 22313.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = stay"),
#  Text(0.04811749691277388, 0.624031007751938, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.05068376341478849, 0.624031007751938, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.039777130781226404, 0.6627906976744186, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.04106026403223371, 0.6705426356589147, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.04234339728324101, 0.6782945736434108, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.043626530534248316, 0.686046511627907, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = leave'),
#  Text(0.04747593028727023, 0.6937984496124031, "['income'] <= 22596.5\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = stay"),
#  Text(0.046192797036262924, 0.686046511627907, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = stay'),
#  Text(0.04875906353827753, 0.686046511627907, "['income'] <= 22634.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = leave"),
#  Text(0.04747593028727023, 0.6782945736434108, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.050042196789284836, 0.6782945736434108, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.05132533004029214, 0.7015503875968992, "['income'] <= 22689.0\nentropy = 0.567\nsamples = 15\nvalue = [2, 13]\nclass = leave"),
#  Text(0.050042196789284836, 0.6937984496124031, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.052608463291299444, 0.6937984496124031, "['income'] <= 22713.5\nentropy = 0.684\nsamples = 11\nvalue = [2, 9]\nclass = leave"),
#  Text(0.05132533004029214, 0.686046511627907, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay'),
#  Text(0.05389159654230675, 0.686046511627907, "['income'] <= 22773.5\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]\nclass = leave"),
#  Text(0.052608463291299444, 0.6782945736434108, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = leave'),
#  Text(0.05517472979331405, 0.6782945736434108, "['income'] <= 22781.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = leave"),
#  Text(0.05389159654230675, 0.6705426356589147, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.05645786304432135, 0.6705426356589147, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.1452955048255921, 0.7093023255813954, "['income'] <= 24341.5\nentropy = 0.993\nsamples = 2488\nvalue = [1121, 1367]\nclass = leave"),
#  Text(0.08055670941480227, 0.7015503875968992, "['income'] <= 24167.5\nentropy = 0.988\nsamples = 92\nvalue = [52, 40]\nclass = stay"),
#  Text(0.07450192438661156, 0.6937984496124031, "['income'] <= 23881.5\nentropy = 0.998\nsamples = 80\nvalue = [42, 38]\nclass = stay"),
#  Text(0.06624175408325204, 0.686046511627907, "['income'] <= 23245.0\nentropy = 0.986\nsamples = 65\nvalue = [37, 28]\nclass = stay"),
#  Text(0.06030726279734326, 0.6782945736434108, "['income'] <= 23188.5\nentropy = 0.983\nsamples = 26\nvalue = [11, 15]\nclass = leave"),
#  Text(0.05902412954633596, 0.6705426356589147, "['income'] <= 23135.0\nentropy = 0.998\nsamples = 21\nvalue = [11, 10]\nclass = stay"),
#  Text(0.0558162964188177, 0.6627906976744186, "['income'] <= 22963.0\nentropy = 0.989\nsamples = 16\nvalue = [7, 9]\nclass = leave"),
#  Text(0.053250029916803096, 0.6550387596899225, "['income'] <= 22851.5\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = stay"),
#  Text(0.05196689666579579, 0.6472868217054264, "['income'] <= 22806.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = stay"),
#  Text(0.05068376341478849, 0.6395348837209303, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.053250029916803096, 0.6395348837209303, "['income'] <= 22819.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = leave"),
#  Text(0.05196689666579579, 0.6317829457364341, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.0545331631678104, 0.6317829457364341, "['income'] <= 22828.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.053250029916803096, 0.624031007751938, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.0558162964188177, 0.624031007751938, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.0545331631678104, 0.6472868217054264, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.058382562920832305, 0.6550387596899225, "['income'] <= 23068.5\nentropy = 0.764\nsamples = 9\nvalue = [2, 7]\nclass = leave"),
#  Text(0.057099429669825, 0.6472868217054264, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.05966569617183961, 0.6472868217054264, "['income'] <= 23108.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = leave"),
#  Text(0.058382562920832305, 0.6395348837209303, "['income'] <= 23088.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = stay"),
#  Text(0.057099429669825, 0.6317829457364341, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.05966569617183961, 0.6317829457364341, "['income'] <= 23106.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.058382562920832305, 0.624031007751938, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.06094882942284691, 0.624031007751938, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.06094882942284691, 0.6395348837209303, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.06223196267385422, 0.6627906976744186, "['income'] <= 23161.0\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = stay"),
#  Text(0.06094882942284691, 0.6550387596899225, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.06351509592486151, 0.6550387596899225, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay'),
#  Text(0.061590396048350565, 0.6705426356589147, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = leave'),
#  Text(0.07217624536916081, 0.6782945736434108, "['income'] <= 23481.5\nentropy = 0.918\nsamples = 39\nvalue = [26, 13]\nclass = stay"),
#  Text(0.06864762892889073, 0.6705426356589147, "['income'] <= 23358.0\nentropy = 0.619\nsamples = 13\nvalue = [11, 2]\nclass = stay"),
#  Text(0.06736449567788343, 0.6627906976744186, "['income'] <= 23302.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = stay"),
#  Text(0.06608136242687612, 0.6550387596899225, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.06864762892889073, 0.6550387596899225, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.06993076217989803, 0.6627906976744186, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = stay'),
#  Text(0.07570486180943091, 0.6705426356589147, "['income'] <= 23641.0\nentropy = 0.983\nsamples = 26\nvalue = [15, 11]\nclass = stay"),
#  Text(0.07249702868191264, 0.6627906976744186, "['income'] <= 23580.5\nentropy = 0.98\nsamples = 12\nvalue = [5, 7]\nclass = leave"),
#  Text(0.07121389543090534, 0.6550387596899225, "['income'] <= 23528.0\nentropy = 1.0\nsamples = 10\nvalue = [5, 5]\nclass = stay"),
#  Text(0.06864762892889073, 0.6472868217054264, "['income'] <= 23496.5\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = leave"),
#  Text(0.06736449567788343, 0.6395348837209303, "['income'] <= 23487.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = stay"),
#  Text(0.06608136242687612, 0.6317829457364341, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.06864762892889073, 0.6317829457364341, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.06993076217989803, 0.6395348837209303, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.07378016193291995, 0.6472868217054264, "['income'] <= 23554.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = stay"),
#  Text(0.07249702868191264, 0.6395348837209303, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.07506329518392725, 0.6395348837209303, "['income'] <= 23566.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.07378016193291995, 0.6317829457364341, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.07634642843493455, 0.6317829457364341, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.07378016193291995, 0.6550387596899225, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.07891269493694916, 0.6627906976744186, "['income'] <= 23730.0\nentropy = 0.863\nsamples = 14\nvalue = [10, 4]\nclass = stay"),
#  Text(0.07762956168594186, 0.6550387596899225, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = stay'),
#  Text(0.08019582818795647, 0.6550387596899225, "['income'] <= 23857.0\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]\nclass = stay"),
#  Text(0.07891269493694916, 0.6472868217054264, "['income'] <= 23736.0\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]\nclass = stay"),
#  Text(0.07762956168594186, 0.6395348837209303, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.08019582818795647, 0.6395348837209303, "['income'] <= 23777.0\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = stay"),
#  Text(0.07891269493694916, 0.6317829457364341, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.08147896143896377, 0.6317829457364341, "['income'] <= 23814.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = leave"),
#  Text(0.08019582818795647, 0.624031007751938, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.08276209468997107, 0.624031007751938, "['income'] <= 23837.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = stay"),
#  Text(0.08147896143896377, 0.6162790697674418, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.08404522794097838, 0.6162790697674418, "['income'] <= 23848.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = leave"),
#  Text(0.08276209468997107, 0.6085271317829457, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.08532836119198568, 0.6085271317829457, "['income'] <= 23853.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.08404522794097838, 0.6007751937984496, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.08661149444299299, 0.6007751937984496, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.08147896143896377, 0.6472868217054264, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.08276209468997107, 0.686046511627907, "['income'] <= 24014.5\nentropy = 0.918\nsamples = 15\nvalue = [5, 10]\nclass = leave"),
#  Text(0.08147896143896377, 0.6782945736434108, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = leave'),
#  Text(0.08404522794097838, 0.6782945736434108, "['income'] <= 24154.5\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]\nclass = stay"),
#  Text(0.08276209468997107, 0.6705426356589147, "['income'] <= 24043.5\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = stay"),
#  Text(0.08147896143896377, 0.6627906976744186, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.08404522794097838, 0.6627906976744186, "['income'] <= 24054.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]\nclass = stay"),
#  Text(0.08276209468997107, 0.6550387596899225, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.08532836119198568, 0.6550387596899225, "['income'] <= 24127.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = stay"),
#  Text(0.08404522794097838, 0.6472868217054264, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.08661149444299299, 0.6472868217054264, "['income'] <= 24148.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.08532836119198568, 0.6395348837209303, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.08789462769400029, 0.6395348837209303, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.08532836119198568, 0.6705426356589147, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.08661149444299299, 0.6937984496124031, "['income'] <= 24281.5\nentropy = 0.65\nsamples = 12\nvalue = [10, 2]\nclass = stay"),
#  Text(0.08532836119198568, 0.686046511627907, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = stay'),
#  Text(0.08789462769400029, 0.686046511627907, "['income'] <= 24298.5\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = stay"),
#  Text(0.08661149444299299, 0.6782945736434108, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.0891777609450076, 0.6782945736434108, "['income'] <= 24322.0\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]\nclass = stay"),
#  Text(0.08789462769400029, 0.6705426356589147, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.0904608941960149, 0.6705426356589147, "['income'] <= 24325.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = stay"),
#  Text(0.0891777609450076, 0.6627906976744186, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.0917440274470222, 0.6627906976744186, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.2100343002363819, 0.7015503875968992, "['income'] <= 24500.0\nentropy = 0.992\nsamples = 2396\nvalue = [1069, 1327]\nclass = leave"),
#  Text(0.16958535624177287, 0.6937984496124031, "['income'] <= 24428.5\nentropy = 0.414\nsamples = 12\nvalue = [1, 11]\nclass = leave"),
#  Text(0.16830222299076558, 0.686046511627907, "['income'] <= 24396.0\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = leave"),
#  Text(0.16701908973975826, 0.6782945736434108, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = leave'),
#  Text(0.16958535624177287, 0.6782945736434108, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.1708684894927802, 0.686046511627907, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = leave'),
#  Text(0.25048324423099094, 0.6937984496124031, "['income'] <= 24569.5\nentropy = 0.992\nsamples = 2384\nvalue = [1068, 1316]\nclass = leave"),
#  Text(0.1734347559947948, 0.686046511627907, "['income'] <= 24509.5\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]\nclass = stay"),
#  Text(0.17215162274378748, 0.6782945736434108, "['income'] <= 24502.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.1708684894927802, 0.6705426356589147, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.1734347559947948, 0.6705426356589147, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.1747178892458021, 0.6782945736434108, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = stay'),
#  Text(0.3275317324671871, 0.686046511627907, "['income'] <= 33653.5\nentropy = 0.992\nsamples = 2377\nvalue = [1062, 1315]\nclass = leave"),
#  Text(0.19183405979476134, 0.6782945736434108, "['income'] <= 32305.0\nentropy = 0.978\nsamples = 520\nvalue = [215, 305]\nclass = leave"),
#  Text(0.1760010224968094, 0.6705426356589147, "['income'] <= 32124.0\nentropy = 0.99\nsamples = 447\nvalue = [197, 250]\nclass = leave"),
#  Text(0.16951643795192387, 0.6627906976744186, "['income'] <= 31940.0\nentropy = 0.987\nsamples = 440\nvalue = [191, 249]\nclass = leave"),
#  Text(0.16039666861517468, 0.6550387596899225, "['income'] <= 31895.0\nentropy = 0.99\nsamples = 428\nvalue = [189, 239]\nclass = leave"),
#  Text(0.15911353536416736, 0.6472868217054264, "['income'] <= 31846.5\nentropy = 0.989\nsamples = 425\nvalue = [186, 239]\nclass = leave"),
#  Text(0.15783040211316007, 0.6395348837209303, "['income'] <= 29406.0\nentropy = 0.99\nsamples = 421\nvalue = [186, 235]\nclass = leave"),
#  Text(0.13830773018865442, 0.6317829457364341, "['income'] <= 28431.5\nentropy = 0.978\nsamples = 284\nvalue = [117, 167]\nclass = leave"),
#  Text(0.11465998535173076, 0.624031007751938, "['income'] <= 27265.0\nentropy = 0.991\nsamples = 234\nvalue = [104, 130]\nclass = leave"),
#  Text(0.0917440274470222, 0.6162790697674418, "['income'] <= 27219.0\nentropy = 0.972\nsamples = 157\nvalue = [63, 94]\nclass = leave"),
#  Text(0.0904608941960149, 0.6085271317829457, "['income'] <= 24588.5\nentropy = 0.977\nsamples = 153\nvalue = [63, 90]\nclass = leave"),
#  Text(0.0891777609450076, 0.6007751937984496, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.0917440274470222, 0.6007751937984496, "['income'] <= 24619.5\nentropy = 0.98\nsamples = 151\nvalue = [63, 88]\nclass = leave"),
#  Text(0.0904608941960149, 0.5930232558139535, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.0930271606980295, 0.5930232558139535, "['income'] <= 24646.0\nentropy = 0.974\nsamples = 148\nvalue = [60, 88]\nclass = leave"),
#  Text(0.0917440274470222, 0.5852713178294574, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.09431029394903681, 0.5852713178294574, "['income'] <= 25687.0\nentropy = 0.978\nsamples = 145\nvalue = [60, 85]\nclass = leave"),
#  Text(0.08119827604030593, 0.5775193798449613, "['income'] <= 25547.5\nentropy = 0.998\nsamples = 70\nvalue = [33, 37]\nclass = leave"),
#  Text(0.07863200953829132, 0.5697674418604651, "['income'] <= 25473.5\nentropy = 0.98\nsamples = 60\nvalue = [25, 35]\nclass = leave"),
#  Text(0.07734887628728401, 0.562015503875969, "['income'] <= 25097.5\nentropy = 0.998\nsamples = 53\nvalue = [25, 28]\nclass = leave"),
#  Text(0.07357967236245005, 0.5542635658914729, "['income'] <= 25035.5\nentropy = 0.96\nsamples = 34\nvalue = [13, 21]\nclass = leave"),
#  Text(0.06989066426580406, 0.5465116279069767, "['income'] <= 24980.0\nentropy = 0.996\nsamples = 26\nvalue = [12, 14]\nclass = leave"),
#  Text(0.06636204782553398, 0.5387596899224806, "['income'] <= 24836.0\nentropy = 0.959\nsamples = 21\nvalue = [8, 13]\nclass = leave"),
#  Text(0.06315421469801571, 0.5310077519379846, "['income'] <= 24747.0\nentropy = 0.997\nsamples = 15\nvalue = [7, 8]\nclass = leave"),
#  Text(0.06058794819600111, 0.5232558139534884, "['income'] <= 24706.5\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]\nclass = leave"),
#  Text(0.05930481494499381, 0.5155038759689923, "['income'] <= 24690.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = leave"),
#  Text(0.058021681693986506, 0.5077519379844961, "['income'] <= 24663.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = leave"),
#  Text(0.0567385484429792, 0.5, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay'),
#  Text(0.05930481494499381, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.06058794819600111, 0.5077519379844961, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.06187108144700841, 0.5155038759689923, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.06572048120003032, 0.5232558139534884, "['income'] <= 24779.5\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]\nclass = stay"),
#  Text(0.06443734794902302, 0.5155038759689923, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.06700361445103763, 0.5155038759689923, "['income'] <= 24784.0\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]\nclass = stay"),
#  Text(0.06572048120003032, 0.5077519379844961, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.06828674770204493, 0.5077519379844961, "['income'] <= 24804.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = stay"),
#  Text(0.06700361445103763, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.06956988095305223, 0.5, "['income'] <= 24818.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = leave"),
#  Text(0.06828674770204493, 0.49224806201550386, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.07085301420405954, 0.49224806201550386, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.06956988095305223, 0.5310077519379846, "['income'] <= 24964.0\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = leave"),
#  Text(0.06828674770204493, 0.5232558139534884, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.07085301420405954, 0.5232558139534884, "['income'] <= 24975.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.06956988095305223, 0.5155038759689923, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.07213614745506684, 0.5155038759689923, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.07341928070607415, 0.5387596899224806, "['income'] <= 25005.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = stay"),
#  Text(0.07213614745506684, 0.5310077519379846, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.07470241395708145, 0.5310077519379846, "['income'] <= 25024.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.07341928070607415, 0.5232558139534884, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.07598554720808876, 0.5232558139534884, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.07726868045909606, 0.5465116279069767, "['income'] <= 25062.5\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]\nclass = leave"),
#  Text(0.07598554720808876, 0.5387596899224806, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.07855181371010336, 0.5387596899224806, "['income'] <= 25072.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = leave"),
#  Text(0.07726868045909606, 0.5310077519379846, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.07983494696111067, 0.5310077519379846, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.08111808021211797, 0.5542635658914729, "['income'] <= 25158.0\nentropy = 0.949\nsamples = 19\nvalue = [12, 7]\nclass = stay"),
#  Text(0.07983494696111067, 0.5465116279069767, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.08240121346312528, 0.5465116279069767, "['income'] <= 25168.0\nentropy = 0.977\nsamples = 17\nvalue = [10, 7]\nclass = stay"),
#  Text(0.08111808021211797, 0.5387596899224806, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.08368434671413258, 0.5387596899224806, "['income'] <= 25239.5\nentropy = 0.954\nsamples = 16\nvalue = [10, 6]\nclass = stay"),
#  Text(0.08240121346312528, 0.5310077519379846, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.08496747996513987, 0.5310077519379846, "['income'] <= 25280.5\nentropy = 0.996\nsamples = 13\nvalue = [7, 6]\nclass = stay"),
#  Text(0.08368434671413258, 0.5232558139534884, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.08625061321614717, 0.5232558139534884, "['income'] <= 25346.0\nentropy = 0.98\nsamples = 12\nvalue = [7, 5]\nclass = stay"),
#  Text(0.08368434671413258, 0.5155038759689923, "['income'] <= 25324.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = stay"),
#  Text(0.08240121346312528, 0.5077519379844961, "['income'] <= 25304.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.08111808021211797, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.08368434671413258, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.08496747996513987, 0.5077519379844961, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.08881687971816178, 0.5155038759689923, "['income'] <= 25429.5\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]\nclass = leave"),
#  Text(0.08753374646715448, 0.5077519379844961, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.09010001296916909, 0.5077519379844961, "['income'] <= 25442.0\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = stay"),
#  Text(0.08881687971816178, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.09138314622017639, 0.5, "['income'] <= 25456.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.09010001296916909, 0.49224806201550386, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.0926662794711837, 0.49224806201550386, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.07991514278929862, 0.562015503875969, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = leave'),
#  Text(0.08376454254232053, 0.5697674418604651, "['income'] <= 25631.5\nentropy = 0.722\nsamples = 10\nvalue = [8, 2]\nclass = stay"),
#  Text(0.08248140929131323, 0.562015503875969, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = stay'),
#  Text(0.08504767579332784, 0.562015503875969, "['income'] <= 25656.0\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = stay"),
#  Text(0.08376454254232053, 0.5542635658914729, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.08633080904433514, 0.5542635658914729, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.10742231185776768, 0.5775193798449613, "['income'] <= 27181.0\nentropy = 0.943\nsamples = 75\nvalue = [27, 48]\nclass = leave"),
#  Text(0.10613917860676038, 0.5697674418604651, "['income'] <= 25709.5\nentropy = 0.935\nsamples = 74\nvalue = [26, 48]\nclass = leave"),
#  Text(0.10485604535575307, 0.562015503875969, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.10742231185776768, 0.562015503875969, "['income'] <= 25719.5\nentropy = 0.944\nsamples = 72\nvalue = [26, 46]\nclass = leave"),
#  Text(0.10613917860676038, 0.5542635658914729, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.10870544510877499, 0.5542635658914729, "['income'] <= 26190.0\nentropy = 0.936\nsamples = 71\nvalue = [25, 46]\nclass = leave"),
#  Text(0.10421447873024943, 0.5465116279069767, "['income'] <= 26131.5\nentropy = 0.811\nsamples = 24\nvalue = [6, 18]\nclass = leave"),
#  Text(0.10293134547924213, 0.5387596899224806, "['income'] <= 26078.5\nentropy = 0.863\nsamples = 21\nvalue = [6, 15]\nclass = leave"),
#  Text(0.10164821222823482, 0.5310077519379846, "['income'] <= 26011.0\nentropy = 0.811\nsamples = 20\nvalue = [5, 15]\nclass = leave"),
#  Text(0.10036507897722752, 0.5232558139534884, "['income'] <= 26002.5\nentropy = 0.874\nsamples = 17\nvalue = [5, 12]\nclass = leave"),
#  Text(0.09908194572622021, 0.5155038759689923, "['income'] <= 25968.5\nentropy = 0.811\nsamples = 16\nvalue = [4, 12]\nclass = leave"),
#  Text(0.09779881247521291, 0.5077519379844961, "['income'] <= 25963.0\nentropy = 0.863\nsamples = 14\nvalue = [4, 10]\nclass = leave"),
#  Text(0.0965156792242056, 0.5, "['income'] <= 25944.0\nentropy = 0.779\nsamples = 13\nvalue = [3, 10]\nclass = leave"),
#  Text(0.0952325459731983, 0.49224806201550386, "['income'] <= 25930.5\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]\nclass = leave"),
#  Text(0.093949412722191, 0.4844961240310077, "['income'] <= 25835.5\nentropy = 0.722\nsamples = 10\nvalue = [2, 8]\nclass = leave"),
#  Text(0.0926662794711837, 0.47674418604651164, "['income'] <= 25807.5\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = leave"),
#  Text(0.09138314622017639, 0.4689922480620155, "['income'] <= 25732.0\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = leave"),
#  Text(0.09010001296916909, 0.46124031007751937, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay'),
#  Text(0.0926662794711837, 0.46124031007751937, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.093949412722191, 0.4689922480620155, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.0952325459731983, 0.47674418604651164, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.0965156792242056, 0.4844961240310077, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.09779881247521291, 0.49224806201550386, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.09908194572622021, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.10036507897722752, 0.5077519379844961, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.10164821222823482, 0.5155038759689923, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.10293134547924213, 0.5232558139534884, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.10421447873024943, 0.5310077519379846, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.10549761198125673, 0.5387596899224806, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.11319641148730056, 0.5465116279069767, "['income'] <= 26394.5\nentropy = 0.973\nsamples = 47\nvalue = [19, 28]\nclass = leave"),
#  Text(0.10806387848327134, 0.5387596899224806, "['income'] <= 26373.5\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]\nclass = stay"),
# ...
#  Text(0.2326881954873557, 0.41472868217054265, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.2352544619893703, 0.41472868217054265, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.2365375952403776, 0.42248062015503873, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.23782072849138491, 0.43023255813953487, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.2391038617423922, 0.437984496124031, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.2429532614954141, 0.44573643410852715, "['income'] <= 34902.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = stay"),
#  Text(0.2416701282444068, 0.437984496124031, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.24423639474642142, 0.437984496124031, "['income'] <= 34913.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = leave"),
#  Text(0.2429532614954141, 0.43023255813953487, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.2455195279974287, 0.43023255813953487, "['income'] <= 34920.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.24423639474642142, 0.42248062015503873, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.24680266124843603, 0.42248062015503873, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.2352544619893703, 0.49224806201550386, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.2365375952403776, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.23782072849138491, 0.5077519379844961, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.2391038617423922, 0.5155038759689923, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.2403869949933995, 0.5232558139534884, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.2416701282444068, 0.5310077519379846, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.2874769828575152, 0.5387596899224806, "['income'] <= 36401.0\nentropy = 0.999\nsamples = 366\nvalue = [176, 190]\nclass = leave"),
#  Text(0.2723049346122062, 0.5310077519379846, "['income'] <= 36173.0\nentropy = 0.983\nsamples = 66\nvalue = [38, 28]\nclass = stay"),
#  Text(0.2670120099518011, 0.5232558139534884, "['income'] <= 36063.5\nentropy = 0.998\nsamples = 57\nvalue = [30, 27]\nclass = stay"),
#  Text(0.2628418268860273, 0.5155038759689923, "['income'] <= 35808.5\nentropy = 0.986\nsamples = 51\nvalue = [29, 22]\nclass = stay"),
#  Text(0.25963399375850904, 0.5077519379844961, "['income'] <= 35758.5\nentropy = 0.998\nsamples = 36\nvalue = [17, 19]\nclass = leave"),
#  Text(0.2583508605075018, 0.5, "['income'] <= 35699.5\nentropy = 0.997\nsamples = 32\nvalue = [17, 15]\nclass = stay"),
#  Text(0.25706772725649446, 0.49224806201550386, "['income'] <= 35639.5\nentropy = 0.999\nsamples = 29\nvalue = [14, 15]\nclass = leave"),
#  Text(0.25578459400548714, 0.4844961240310077, "['income'] <= 35612.5\nentropy = 0.98\nsamples = 24\nvalue = [14, 10]\nclass = stay"),
#  Text(0.2545014607544798, 0.47674418604651164, "['income'] <= 35337.0\nentropy = 0.994\nsamples = 22\nvalue = [12, 10]\nclass = stay"),
#  Text(0.25193519425246524, 0.4689922480620155, "['income'] <= 35300.5\nentropy = 0.881\nsamples = 10\nvalue = [7, 3]\nclass = stay"),
#  Text(0.2506520610014579, 0.46124031007751937, "['income'] <= 35262.0\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = stay"),
#  Text(0.24936892775045064, 0.45348837209302323, "['income'] <= 35233.0\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]\nclass = stay"),
#  Text(0.24808579449944332, 0.44573643410852715, "['income'] <= 35186.0\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = stay"),
#  Text(0.24680266124843603, 0.437984496124031, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.24936892775045064, 0.437984496124031, "['income'] <= 35208.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = leave"),
#  Text(0.24808579449944332, 0.43023255813953487, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay'),
#  Text(0.2506520610014579, 0.43023255813953487, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.2506520610014579, 0.44573643410852715, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.25193519425246524, 0.45348837209302323, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.25321832750347256, 0.46124031007751937, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.25706772725649446, 0.4689922480620155, "['income'] <= 35365.5\nentropy = 0.98\nsamples = 12\nvalue = [5, 7]\nclass = leave"),
#  Text(0.25578459400548714, 0.46124031007751937, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.2583508605075018, 0.46124031007751937, "['income'] <= 35433.5\nentropy = 1.0\nsamples = 10\nvalue = [5, 5]\nclass = stay"),
#  Text(0.25706772725649446, 0.45348837209302323, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.25963399375850904, 0.45348837209302323, "['income'] <= 35465.0\nentropy = 0.954\nsamples = 8\nvalue = [3, 5]\nclass = leave"),
#  Text(0.2583508605075018, 0.44573643410852715, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.26091712700951636, 0.44573643410852715, "['income'] <= 35474.0\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]\nclass = stay"),
#  Text(0.25963399375850904, 0.437984496124031, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.2622002602605237, 0.437984496124031, "['income'] <= 35492.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = leave"),
#  Text(0.26091712700951636, 0.43023255813953487, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.263483393511531, 0.43023255813953487, "['income'] <= 35532.0\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = stay"),
#  Text(0.2622002602605237, 0.42248062015503873, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.26476652676253826, 0.42248062015503873, "['income'] <= 35568.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = leave"),
#  Text(0.263483393511531, 0.41472868217054265, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.2660496600135456, 0.41472868217054265, "['income'] <= 35590.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay"),
#  Text(0.26476652676253826, 0.4069767441860465, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.2673327932645529, 0.4069767441860465, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.25706772725649446, 0.47674418604651164, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.2583508605075018, 0.4844961240310077, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = leave'),
#  Text(0.25963399375850904, 0.49224806201550386, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.26091712700951636, 0.5, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.2660496600135456, 0.5077519379844961, "['income'] <= 36033.5\nentropy = 0.722\nsamples = 15\nvalue = [12, 3]\nclass = stay"),
#  Text(0.263483393511531, 0.5, "['income'] <= 35950.5\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]\nclass = stay"),
#  Text(0.2622002602605237, 0.49224806201550386, "['income'] <= 35934.0\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = stay"),
#  Text(0.26091712700951636, 0.4844961240310077, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.263483393511531, 0.4844961240310077, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.26476652676253826, 0.49224806201550386, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = stay'),
#  Text(0.2686159265155602, 0.5, "['income'] <= 36055.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = stay"),
#  Text(0.2673327932645529, 0.49224806201550386, "['income'] <= 36042.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = leave"),
#  Text(0.2660496600135456, 0.4844961240310077, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay'),
#  Text(0.2686159265155602, 0.4844961240310077, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.2698990597665675, 0.49224806201550386, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.2711821930175748, 0.5155038759689923, "['income'] <= 36108.0\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = leave"),
#  Text(0.2698990597665675, 0.5077519379844961, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.2724653262685821, 0.5077519379844961, "['income'] <= 36130.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = leave"),
#  Text(0.2711821930175748, 0.5, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay'),
#  Text(0.27374845951958937, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.2775978592726113, 0.5232558139534884, "['income'] <= 36308.0\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]\nclass = stay"),
#  Text(0.276314726021604, 0.5155038759689923, "['income'] <= 36278.0\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = stay"),
#  Text(0.2750315927705967, 0.5077519379844961, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.2775978592726113, 0.5077519379844961, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay'),
#  Text(0.2788809925236186, 0.5155038759689923, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = stay'),
#  Text(0.3026490311028242, 0.5310077519379846, "['income'] <= 36545.5\nentropy = 0.995\nsamples = 300\nvalue = [138, 162]\nclass = leave"),
#  Text(0.3013658978518169, 0.5232558139534884, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.3039321643538315, 0.5232558139534884, "['income'] <= 36587.0\nentropy = 0.997\nsamples = 296\nvalue = [138, 158]\nclass = leave"),
#  Text(0.3026490311028242, 0.5155038759689923, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.30521529760483884, 0.5155038759689923, "['income'] <= 36983.5\nentropy = 0.996\nsamples = 294\nvalue = [136, 158]\nclass = leave"),
#  Text(0.29034899595449637, 0.5077519379844961, "['income'] <= 36772.0\nentropy = 0.871\nsamples = 24\nvalue = [7, 17]\nclass = leave"),
#  Text(0.2877827294524818, 0.5, "['income'] <= 36705.5\nentropy = 1.0\nsamples = 10\nvalue = [5, 5]\nclass = stay"),
#  Text(0.28649959620147447, 0.49224806201550386, "['income'] <= 36636.0\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = leave"),
#  Text(0.28521646295046715, 0.4844961240310077, "['income'] <= 36613.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = leave"),
#  Text(0.2839333296994599, 0.47674418604651164, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.28649959620147447, 0.47674418604651164, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.2877827294524818, 0.4844961240310077, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.2890658627034891, 0.49224806201550386, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = stay'),
#  Text(0.292915262456511, 0.5, "['income'] <= 36801.0\nentropy = 0.592\nsamples = 14\nvalue = [2, 12]\nclass = leave"),
#  Text(0.2916321292055037, 0.49224806201550386, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.2941983957075183, 0.49224806201550386, "['income'] <= 36819.0\nentropy = 0.684\nsamples = 11\nvalue = [2, 9]\nclass = leave"),
#  Text(0.292915262456511, 0.4844961240310077, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.2954815289585256, 0.4844961240310077, "['income'] <= 36957.5\nentropy = 0.469\nsamples = 10\nvalue = [1, 9]\nclass = leave"),
#  Text(0.2941983957075183, 0.47674418604651164, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = leave'),
#  Text(0.2967646622095329, 0.47674418604651164, "['income'] <= 36965.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = leave"),
#  Text(0.2954815289585256, 0.4689922480620155, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay'),
#  Text(0.2980477954605402, 0.4689922480620155, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.32008159925518126, 0.5077519379844961, "['income'] <= 37076.5\nentropy = 0.999\nsamples = 270\nvalue = [129, 141]\nclass = leave"),
#  Text(0.31879846600417394, 0.5, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = stay'),
#  Text(0.3213647325061885, 0.5, "['income'] <= 41840.0\nentropy = 0.997\nsamples = 265\nvalue = [124, 141]\nclass = leave"),
#  Text(0.32008159925518126, 0.49224806201550386, "['income'] <= 39709.0\nentropy = 0.997\nsamples = 264\nvalue = [123, 141]\nclass = leave"),
#  Text(0.3093153093209481, 0.4844961240310077, "['income'] <= 39332.0\nentropy = 1.0\nsamples = 165\nvalue = [82, 83]\nclass = leave"),
#  Text(0.3018971952135621, 0.47674418604651164, "['income'] <= 39246.5\nentropy = 0.995\nsamples = 142\nvalue = [65, 77]\nclass = leave"),
#  Text(0.3006140619625548, 0.4689922480620155, "['income'] <= 38778.5\nentropy = 0.996\nsamples = 140\nvalue = [65, 75]\nclass = leave"),
#  Text(0.2960428997558413, 0.46124031007751937, "['income'] <= 38709.0\nentropy = 0.987\nsamples = 106\nvalue = [46, 60]\nclass = leave"),
#  Text(0.294759766504834, 0.45348837209302323, "['income'] <= 38657.0\nentropy = 0.995\nsamples = 100\nvalue = [46, 54]\nclass = leave"),
#  Text(0.29347663325382667, 0.44573643410852715, "['income'] <= 38488.0\nentropy = 0.989\nsamples = 96\nvalue = [42, 54]\nclass = leave"),
#  Text(0.2921935000028194, 0.437984496124031, "['income'] <= 38423.0\nentropy = 0.998\nsamples = 89\nvalue = [42, 47]\nclass = leave"),
#  Text(0.2843343088403997, 0.43023255813953487, "['income'] <= 38108.5\nentropy = 1.0\nsamples = 84\nvalue = [41, 43]\nclass = leave"),
#  Text(0.2724653262685821, 0.42248062015503873, "['income'] <= 38038.0\nentropy = 0.99\nsamples = 59\nvalue = [26, 33]\nclass = leave"),
#  Text(0.2711821930175748, 0.41472868217054265, "['income'] <= 38014.5\nentropy = 0.998\nsamples = 55\nvalue = [26, 29]\nclass = leave"),
#  Text(0.2698990597665675, 0.4069767441860465, "['income'] <= 37084.0\nentropy = 0.996\nsamples = 54\nvalue = [25, 29]\nclass = leave"),
#  Text(0.2686159265155602, 0.3992248062015504, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.2711821930175748, 0.3992248062015504, "['income'] <= 37091.5\nentropy = 0.998\nsamples = 53\nvalue = [25, 28]\nclass = leave"),
#  Text(0.2698990597665675, 0.39147286821705424, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.2724653262685821, 0.39147286821705424, "['income'] <= 37118.0\nentropy = 0.996\nsamples = 52\nvalue = [24, 28]\nclass = leave"),
#  Text(0.2711821930175748, 0.38372093023255816, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.27374845951958937, 0.38372093023255816, "['income'] <= 37199.0\nentropy = 0.999\nsamples = 50\nvalue = [24, 26]\nclass = leave"),
#  Text(0.2711821930175748, 0.375968992248062, "['income'] <= 37168.5\nentropy = 0.918\nsamples = 9\nvalue = [6, 3]\nclass = stay"),
#  Text(0.2698990597665675, 0.3682170542635659, "['income'] <= 37152.5\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = stay"),
#  Text(0.2686159265155602, 0.36046511627906974, "['income'] <= 37125.0\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]\nclass = stay"),
#  Text(0.2673327932645529, 0.35271317829457366, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.2698990597665675, 0.35271317829457366, "['income'] <= 37131.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = stay"),
#  Text(0.2686159265155602, 0.3449612403100775, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.2711821930175748, 0.3449612403100775, "['income'] <= 37139.0\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = stay"),
#  Text(0.2698990597665675, 0.3372093023255814, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.2724653262685821, 0.3372093023255814, "['income'] <= 37147.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = stay"),
#  ...]

# %% [markdown]
# Whoa!
#
# What is the accuracy of this model?

# %%
# Your code goes here

sum(pred == mtc_clean['leave']) / len(pred)
# Out:
# 0.9881858229875851

# %% [markdown]
# Killing it!

# %% [markdown]
# ## Cross-validation
#
# Or:  maybe not.  Will you get promoted or ... fired?
#
# This model is excessively complicated.  It has figured out how to classify the target perfectly *in the training data*. It has essentially just memorize the training data.  However, when it encounters new data **it will suck**. That's because new data will have patterns that were not in the training data (this is the nature of sampling) and the overfit model will get badly confused.
#
# To demonstrate this we will use cross-validation.
#
# The simplest version of cross-validation uses a training set and a testing or validation set. (This is called the validation set method.) Simply, we divide the data that we have into two parts: 80% goes into the training set and 20% into the testing set. (80/20 is a common choice.) That division is done randomly using the `sample()` function.

# %%
# divide mtc_clean into train and test
train = mtc_clean.sample(frac=0.8, random_state=200) # 80% of data for training
test = mtc_clean.drop(train.index) # the remaining 20%

# %% [markdown]
# `random_state` is a seed that ensures the same split when set to 200 (an arbitrary choice). This will make our results comparable.

# %%
train.head()
# Out:
#      college  income  overage  leftover   house  handset_price  \
# 3773     yes   80751        0        54  298898            371
# 2835      no   75827        0        58  169117            264
# 432       no  114384       71         0  204766            814
# 3959      no   84795        0        14  914009            302
# 409       no   85012        0         0  485532            380
#
#       over_15mins_calls_per_month  average_call_duration  \
# 3773                          1.0                      2
# 2835                          1.0                      2
# 432                           5.0                     14
# 3959                          1.0                      5
# 409                           0.0                      9
#
#      reported_satisfaction reported_usage_level considering_change_of_plan  \
# 3773                  high                  low                         no
# 2835                  high                  low                         no
# 432                    low                  low                        yes
# 3959                  high                  low                         no
# 409                   high                  low                         no
#
#       leave     id reported _usage_level
# 3773   STAY  10317                   low
# 2835   STAY   6724                   low
# 432    STAY   4530                   low
# 3959   STAY   7738                   low
# 409   LEAVE   7788                   low

# %%
test.head()
# Out:
#    college  income  overage  leftover   house  handset_price  \
# 2       no   30883       60         0  647281            211
# 18      no   50117      216         0  156554            324
# 19      no   64138        0        34  274984            268
# 38      no  158711      192        57  271701            557
# 40     yes   67761        0        46  155536            316
#
#     over_15mins_calls_per_month  average_call_duration reported_satisfaction  \
# 2                           3.0                      8                   low
# 18                         14.0                      9                   low
# 19                          0.0                      1                   low
# 38                          3.0                      1                   low
# 40                          0.0                      1                  high
#
#    reported_usage_level considering_change_of_plan  leave     id  \
# 2                   low                        yes   STAY   7425
# 18                  low                         no  LEAVE  18537
# 19                  low                         no  LEAVE   3419
# 38                 high                        yes  LEAVE   8132
# 40                 high                        yes  LEAVE  14134
#
#    reported _usage_level
# 2                    low
# 18                   low
# 19                   low
# 38                  high
# 40                  high

# %% [markdown]
# The cross validation procedure is to create the model using the train data and then evaluate it--that is, get predictions--using the test data. Accuracy of the model is therefore calculated using the test data. This way, we get an accurate picture of how the model will perform in the wild, with new data.
#
# Make sure to leave out the `max_depth` argument.

# %%
# Initialize the classifier.  Leave out max_depth
# Your code goes here
money_tree = DecisionTreeClassifier(criterion = "entropy")

# %%
# Fit the model using train
# Your code goes here
money_tree = money_tree.fit(X = train[['income']],
                            y = train['leave'])

# %%
# Predict using test
# Your code goes here
pred = money_tree.predict(X = test[['income']])

# %%
# Calculate model accuracy on the test set
# Your code goes here
sum(pred == test['leave']) / len(test)
# Out:
# 0.5125125125125125

# %%
test['leave'].value_counts(normalize = True)
# Out:
# leave
# STAY     0.515516
# LEAVE    0.484484
# Name: proportion, dtype: float64

# %% [markdown]
# Better or worse than the simpler model?
#
# Let's explore this further.  More complicated models are good--up to a point.  Choose a `max_depth` argument greater than 2 and see if you can improve on the simple model's accuracy without getting too complex and overfitting.

# %%
# Initialize the classifier--chose a max_depth > 2
# Your code goes here
another_tree= DecisionTreeClassifier(criterion = "entropy", max_depth = 4)

# %%
# Fit the model using train
# Your code goes here
another_tree = train_tree.fit(train [['income']], train ['leave']) # Pass target variable as a positional argument

plot_tree(train_tree,
          feature_names=[['income']],
          class_names=['stay', 'leave'],
          filled=True)
# Out:
# [Text(0.4642857142857143, 0.9, "['income'] <= 99993.0\nentropy = 1.0\nsamples = 3995\nvalue = [1984, 2011]\nclass = leave"),
#  Text(0.14285714285714285, 0.7, "['income'] <= 20137.5\nentropy = 0.991\nsamples = 2654\nvalue = [1180, 1474]\nclass = leave"),
#  Text(0.07142857142857142, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = leave'),
#  Text(0.21428571428571427, 0.5, "['income'] <= 20247.5\nentropy = 0.991\nsamples = 2651\nvalue = [1180, 1471]\nclass = leave"),
#  Text(0.14285714285714285, 0.3, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = stay'),
#  Text(0.2857142857142857, 0.3, "['income'] <= 25346.0\nentropy = 0.991\nsamples = 2647\nvalue = [1176, 1471]\nclass = leave"),
#  Text(0.21428571428571427, 0.1, 'entropy = 1.0\nsamples = 253\nvalue = [125, 128]\nclass = leave'),
#  Text(0.35714285714285715, 0.1, 'entropy = 0.989\nsamples = 2394\nvalue = [1051, 1343]\nclass = leave'),
#  Text(0.7857142857142857, 0.7, "['income'] <= 159576.0\nentropy = 0.971\nsamples = 1341\nvalue = [804, 537]\nclass = stay"),
#  Text(0.7142857142857143, 0.5, "['income'] <= 105440.0\nentropy = 0.973\nsamples = 1332\nvalue = [795, 537]\nclass = stay"),
#  Text(0.5714285714285714, 0.3, "['income'] <= 104820.0\nentropy = 0.85\nsamples = 116\nvalue = [84, 32]\nclass = stay"),
#  Text(0.5, 0.1, 'entropy = 0.884\nsamples = 106\nvalue = [74, 32]\nclass = stay'),
#  Text(0.6428571428571429, 0.1, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = stay'),
#  Text(0.8571428571428571, 0.3, "['income'] <= 153493.0\nentropy = 0.979\nsamples = 1216\nvalue = [711, 505]\nclass = stay"),
#  Text(0.7857142857142857, 0.1, 'entropy = 0.974\nsamples = 1082\nvalue = [644, 438]\nclass = stay'),
#  Text(0.9285714285714286, 0.1, 'entropy = 1.0\nsamples = 134\nvalue = [67, 67]\nclass = stay'),
#  Text(0.8571428571428571, 0.5, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = stay')]

# %%
# Predict using test
# Your code goes here
pred = train_tree.predict(X = test[['income']])
print(pred)
# Out:
# ['STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE'
#  'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY'
#  'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY'
#  'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY'
#  'LEAVE' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE'
#  'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY'
#  'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'LEAVE'
#  'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY'
#  'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'LEAVE'
#  'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE'
#  'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE'
#  'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY'
#  'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY'
#  'LEAVE' 'LEAVE' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE'
#  'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY'
#  'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE'
#  'LEAVE' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY'
#  'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY'
#  'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'LEAVE'
#  'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY'
#  'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'LEAVE' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'STAY'
#  'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY'
#  'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'STAY' 'LEAVE' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY'
#  'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY'
#  'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY'
#  'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY'
#  'LEAVE' 'LEAVE' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY'
#  'LEAVE' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY'
#  'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE'
#  'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE'
#  'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY'
#  'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY'
#  'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY'
#  'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY'
#  'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'STAY' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY'
#  'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY'
#  'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE'
#  'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY'
#  'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE'
#  'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY'
#  'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY'
#  'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY'
#  'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE'
#  'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'LEAVE'
#  'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY'
#  'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'LEAVE'
#  'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY'
#  'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'LEAVE'
#  'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY'
#  'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'LEAVE'
#  'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE'
#  'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY'
#  'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY'
#  'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE'
#  'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'STAY' 'STAY' 'LEAVE' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE'
#  'LEAVE' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'STAY'
#  'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY'
#  'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY'
#  'LEAVE' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE'
#  'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY'
#  'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'LEAVE'
#  'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY'
#  'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY'
#  'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE'
#  'LEAVE' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE'
#  'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'STAY'
#  'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY'
#  'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE'
#  'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY'
#  'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY'
#  'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE'
#  'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE'
#  'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY'
#  'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE'
#  'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'LEAVE' 'LEAVE' 'STAY' 'STAY'
#  'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE'
#  'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY'
#  'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'LEAVE'
#  'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE'
#  'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'LEAVE'
#  'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'LEAVE'
#  'LEAVE' 'STAY' 'STAY' 'LEAVE' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY'
#  'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE'
#  'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE'
#  'LEAVE' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'LEAVE'
#  'LEAVE' 'LEAVE' 'LEAVE' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY'
#  'STAY' 'LEAVE' 'LEAVE' 'LEAVE' 'STAY' 'LEAVE' 'LEAVE' 'LEAVE' 'STAY'
#  'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY' 'STAY' 'STAY' 'STAY' 'LEAVE' 'STAY'
#  'LEAVE' 'LEAVE' 'STAY' 'STAY' 'STAY' 'LEAVE']

# %%
# Calculate model accuracy on the test set
# Your code goes here
sum(pred == test['leave']) / len(test)
# Out:
# 0.5555555555555556

# %% [markdown]
# ## Additional predictors
#
# Pick one additional variable to use as a predictor--one that you think is a driver of churn at MegaTelCo, based on your EDA.
#
# Refit the model using your best performing `max_depth` setting, with `income` and your chosen second predictor.
#
# How does this model perform on the test set?
#
# Adding a predictor makes for a more complicated model.  But complicated is good -- as long as it does not tip over into overfitting.

# %%
# Initialize the classifier--chose a max_depth > 2
# Your code goes here
another_tree = DecisionTreeClassifier(criterion = "entropy", max_depth = 6)

# %%
# Fit the model using the modified train DataFrame
another_tree = another_tree.fit(X = train[['income', 'house']],
                            y = train['leave'])

# Correct the feature_names for plot_tree
plot_tree(another_tree,
          feature_names=['income', 'house'],  # List individual features
          class_names=['stay', 'leave'],
          filled=True)
# Out:
# [Text(0.5151515151515151, 0.9285714285714286, 'house <= 600255.5\nentropy = 1.0\nsamples = 3995\nvalue = [1984, 2011]\nclass = leave'),
#  Text(0.22537878787878787, 0.7857142857142857, 'house <= 247259.0\nentropy = 0.976\nsamples = 2618\nvalue = [1546, 1072]\nclass = stay'),
#  Text(0.10606060606060606, 0.6428571428571429, 'house <= 243167.0\nentropy = 0.995\nsamples = 854\nvalue = [463, 391]\nclass = stay'),
#  Text(0.07575757575757576, 0.5, 'house <= 242218.0\nentropy = 0.993\nsamples = 825\nvalue = [454, 371]\nclass = stay'),
#  Text(0.06060606060606061, 0.35714285714285715, 'income <= 79013.5\nentropy = 0.993\nsamples = 820\nvalue = [449, 371]\nclass = stay'),
#  Text(0.030303030303030304, 0.21428571428571427, 'income <= 74184.5\nentropy = 1.0\nsamples = 443\nvalue = [225, 218]\nclass = stay'),
#  Text(0.015151515151515152, 0.07142857142857142, 'entropy = 0.998\nsamples = 419\nvalue = [220, 199]\nclass = stay'),
#  Text(0.045454545454545456, 0.07142857142857142, 'entropy = 0.738\nsamples = 24\nvalue = [5, 19]\nclass = leave'),
#  Text(0.09090909090909091, 0.21428571428571427, 'income <= 80824.5\nentropy = 0.974\nsamples = 377\nvalue = [224, 153]\nclass = stay'),
#  Text(0.07575757575757576, 0.07142857142857142, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = stay'),
#  Text(0.10606060606060606, 0.07142857142857142, 'entropy = 0.979\nsamples = 369\nvalue = [216, 153]\nclass = stay'),
#  Text(0.09090909090909091, 0.35714285714285715, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = stay'),
#  Text(0.13636363636363635, 0.5, 'income <= 27795.0\nentropy = 0.894\nsamples = 29\nvalue = [9, 20]\nclass = leave'),
#  Text(0.12121212121212122, 0.35714285714285715, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.15151515151515152, 0.35714285714285715, 'income <= 40558.5\nentropy = 0.826\nsamples = 27\nvalue = [7, 20]\nclass = leave'),
#  Text(0.13636363636363635, 0.21428571428571427, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.16666666666666666, 0.21428571428571427, 'house <= 246445.0\nentropy = 0.887\nsamples = 23\nvalue = [7, 16]\nclass = leave'),
#  Text(0.15151515151515152, 0.07142857142857142, 'entropy = 0.792\nsamples = 21\nvalue = [5, 16]\nclass = leave'),
#  Text(0.18181818181818182, 0.07142857142857142, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.3446969696969697, 0.6428571428571429, 'income <= 21501.5\nentropy = 0.962\nsamples = 1764\nvalue = [1083, 681]\nclass = stay'),
#  Text(0.2727272727272727, 0.5, 'income <= 20606.5\nentropy = 0.758\nsamples = 32\nvalue = [25, 7]\nclass = stay'),
#  Text(0.24242424242424243, 0.35714285714285715, 'income <= 20569.0\nentropy = 0.996\nsamples = 13\nvalue = [7, 6]\nclass = stay'),
#  Text(0.22727272727272727, 0.21428571428571427, 'income <= 20440.5\nentropy = 0.946\nsamples = 11\nvalue = [7, 4]\nclass = stay'),
#  Text(0.21212121212121213, 0.07142857142857142, 'entropy = 1.0\nsamples = 8\nvalue = [4, 4]\nclass = stay'),
#  Text(0.24242424242424243, 0.07142857142857142, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.25757575757575757, 0.21428571428571427, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.30303030303030304, 0.35714285714285715, 'house <= 280243.5\nentropy = 0.297\nsamples = 19\nvalue = [18, 1]\nclass = stay'),
#  Text(0.2878787878787879, 0.21428571428571427, 'house <= 269832.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = stay'),
#  Text(0.2727272727272727, 0.07142857142857142, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.30303030303030304, 0.07142857142857142, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.3181818181818182, 0.21428571428571427, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = stay'),
#  Text(0.4166666666666667, 0.5, 'house <= 561254.0\nentropy = 0.964\nsamples = 1732\nvalue = [1058, 674]\nclass = stay'),
#  Text(0.3787878787878788, 0.35714285714285715, 'house <= 488622.5\nentropy = 0.969\nsamples = 1585\nvalue = [957, 628]\nclass = stay'),
#  Text(0.3484848484848485, 0.21428571428571427, 'house <= 376510.5\nentropy = 0.959\nsamples = 1266\nvalue = [784, 482]\nclass = stay'),
#  Text(0.3333333333333333, 0.07142857142857142, 'entropy = 0.975\nsamples = 760\nvalue = [450, 310]\nclass = stay'),
#  Text(0.36363636363636365, 0.07142857142857142, 'entropy = 0.925\nsamples = 506\nvalue = [334, 172]\nclass = stay'),
#  Text(0.4090909090909091, 0.21428571428571427, 'income <= 154513.0\nentropy = 0.995\nsamples = 319\nvalue = [173, 146]\nclass = stay'),
#  Text(0.3939393939393939, 0.07142857142857142, 'entropy = 0.993\nsamples = 315\nvalue = [173, 142]\nclass = stay'),
#  Text(0.42424242424242425, 0.07142857142857142, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = leave'),
#  Text(0.45454545454545453, 0.35714285714285715, 'house <= 564649.5\nentropy = 0.897\nsamples = 147\nvalue = [101, 46]\nclass = stay'),
#  Text(0.4393939393939394, 0.21428571428571427, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = stay'),
#  Text(0.4696969696969697, 0.21428571428571427, 'income <= 128090.5\nentropy = 0.916\nsamples = 139\nvalue = [93, 46]\nclass = stay'),
#  Text(0.45454545454545453, 0.07142857142857142, 'entropy = 0.88\nsamples = 117\nvalue = [82, 35]\nclass = stay'),
#  Text(0.48484848484848486, 0.07142857142857142, 'entropy = 1.0\nsamples = 22\nvalue = [11, 11]\nclass = stay'),
#  Text(0.8049242424242424, 0.7857142857142857, 'income <= 99826.0\nentropy = 0.902\nsamples = 1377\nvalue = [438, 939]\nclass = leave'),
#  Text(0.6856060606060606, 0.6428571428571429, 'income <= 69540.0\nentropy = 0.681\nsamples = 909\nvalue = [164, 745]\nclass = leave'),
#  Text(0.5984848484848485, 0.5, 'income <= 69226.5\nentropy = 0.719\nsamples = 620\nvalue = [123, 497]\nclass = leave'),
#  Text(0.5606060606060606, 0.35714285714285715, 'house <= 959837.5\nentropy = 0.711\nsamples = 616\nvalue = [120, 496]\nclass = leave'),
#  Text(0.5303030303030303, 0.21428571428571427, 'house <= 921457.5\nentropy = 0.729\nsamples = 560\nvalue = [114, 446]\nclass = leave'),
#  Text(0.5151515151515151, 0.07142857142857142, 'entropy = 0.686\nsamples = 487\nvalue = [89, 398]\nclass = leave'),
#  Text(0.5454545454545454, 0.07142857142857142, 'entropy = 0.927\nsamples = 73\nvalue = [25, 48]\nclass = leave'),
#  Text(0.5909090909090909, 0.21428571428571427, 'house <= 966689.5\nentropy = 0.491\nsamples = 56\nvalue = [6, 50]\nclass = leave'),
#  Text(0.5757575757575758, 0.07142857142857142, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = leave'),
#  Text(0.6060606060606061, 0.07142857142857142, 'entropy = 0.567\nsamples = 45\nvalue = [6, 39]\nclass = leave'),
#  Text(0.6363636363636364, 0.35714285714285715, 'house <= 922823.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = stay'),
#  Text(0.6212121212121212, 0.21428571428571427, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay'),
#  Text(0.6515151515151515, 0.21428571428571427, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.7727272727272727, 0.5, 'house <= 638623.0\nentropy = 0.589\nsamples = 289\nvalue = [41, 248]\nclass = leave'),
#  Text(0.7121212121212122, 0.35714285714285715, 'house <= 633210.0\nentropy = 0.89\nsamples = 26\nvalue = [8, 18]\nclass = leave'),
#  Text(0.6818181818181818, 0.21428571428571427, 'income <= 96686.0\nentropy = 0.773\nsamples = 22\nvalue = [5, 17]\nclass = leave'),
#  Text(0.6666666666666666, 0.07142857142857142, 'entropy = 0.702\nsamples = 21\nvalue = [4, 17]\nclass = leave'),
#  Text(0.696969696969697, 0.07142857142857142, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = stay'),
#  Text(0.7424242424242424, 0.21428571428571427, 'house <= 634878.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = stay'),
#  Text(0.7272727272727273, 0.07142857142857142, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = stay'),
#  Text(0.7575757575757576, 0.07142857142857142, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = stay'),
#  Text(0.8333333333333334, 0.35714285714285715, 'house <= 834783.5\nentropy = 0.545\nsamples = 263\nvalue = [33, 230]\nclass = leave'),
#  Text(0.803030303030303, 0.21428571428571427, 'income <= 93536.5\nentropy = 0.631\nsamples = 126\nvalue = [20, 106]\nclass = leave'),
#  Text(0.7878787878787878, 0.07142857142857142, 'entropy = 0.533\nsamples = 99\nvalue = [12, 87]\nclass = leave'),
#  Text(0.8181818181818182, 0.07142857142857142, 'entropy = 0.877\nsamples = 27\nvalue = [8, 19]\nclass = leave'),
#  Text(0.8636363636363636, 0.21428571428571427, 'house <= 876145.0\nentropy = 0.453\nsamples = 137\nvalue = [13, 124]\nclass = leave'),
#  Text(0.8484848484848485, 0.07142857142857142, 'entropy = 0.151\nsamples = 46\nvalue = [1, 45]\nclass = leave'),
#  Text(0.8787878787878788, 0.07142857142857142, 'entropy = 0.563\nsamples = 91\nvalue = [12, 79]\nclass = leave'),
#  Text(0.9242424242424242, 0.6428571428571429, 'income <= 158903.5\nentropy = 0.979\nsamples = 468\nvalue = [274, 194]\nclass = stay'),
#  Text(0.8939393939393939, 0.5, 'house <= 606612.0\nentropy = 0.983\nsamples = 457\nvalue = [264, 193]\nclass = stay'),
#  Text(0.8787878787878788, 0.35714285714285715, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = stay'),
#  Text(0.9090909090909091, 0.35714285714285715, 'house <= 608674.5\nentropy = 0.984\nsamples = 453\nvalue = [260, 193]\nclass = stay'),
#  Text(0.8939393939393939, 0.21428571428571427, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = leave'),
#  Text(0.9242424242424242, 0.21428571428571427, 'house <= 680774.0\nentropy = 0.983\nsamples = 451\nvalue = [260, 191]\nclass = stay'),
#  Text(0.9090909090909091, 0.07142857142857142, 'entropy = 0.904\nsamples = 75\nvalue = [51, 24]\nclass = stay'),
#  Text(0.9393939393939394, 0.07142857142857142, 'entropy = 0.991\nsamples = 376\nvalue = [209, 167]\nclass = stay'),
#  Text(0.9545454545454546, 0.5, 'house <= 821752.5\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]\nclass = stay'),
#  Text(0.9393939393939394, 0.35714285714285715, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = stay'),
#  Text(0.9696969696969697, 0.35714285714285715, 'house <= 843422.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = stay'),
#  Text(0.9545454545454546, 0.21428571428571427, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = leave'),
#  Text(0.9848484848484849, 0.21428571428571427, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = stay')]

# %%
# Calculate model accuracy on the test set
# Your code goes here

sum(pred == test['leave']) / len(pred)
# Out:
# 0.5555555555555556
